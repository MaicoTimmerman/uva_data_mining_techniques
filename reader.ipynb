# %%
import pandas as pd

types = {'id':str, 'time':str, 'variable':str, 'value':float}
parse_dates = ['time']
df = pd.read_csv('dataset_mood_smartphone.csv', index_col=0, dtype=types, parse_dates=parse_dates)

# %% [markdown]
# ## Basic overview of the data

# %%
df.head()
# Out:
#         id                time variable  value
# 1  AS14.01 2014-02-26 13:00:00     mood    6.0
# 2  AS14.01 2014-02-26 15:00:00     mood    6.0
# 3  AS14.01 2014-02-26 18:00:00     mood    6.0
# 4  AS14.01 2014-02-26 21:00:00     mood    7.0
# 5  AS14.01 2014-02-27 09:00:00     mood    6.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 376912 entries, 1 to 2784435
# Data columns (total 4 columns):
# id          376912 non-null object
# time        376912 non-null datetime64[ns]
# variable    376912 non-null object
# value       376710 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 14.4+ MB

# %%
df.variable.unique()
# Out:
# array(['mood', 'circumplex.arousal', 'circumplex.valence', 'activity',
#        'screen', 'call', 'sms', 'appCat.builtin', 'appCat.communication',
#        'appCat.entertainment', 'appCat.finance', 'appCat.game',
#        'appCat.office', 'appCat.other', 'appCat.social', 'appCat.travel',
#        'appCat.unknown', 'appCat.utilities', 'appCat.weather'],
#       dtype=object)

# %%
df.variable.value_counts().plot.bar()

# %%
df.id.value_counts()
# Out:
# AS14.01    21999
# AS14.23    21852
# AS14.13    19592
# AS14.28    19276
# AS14.06    18092
# AS14.29    17499
# AS14.12    17311
# AS14.30    17279
# AS14.26    16403
# AS14.33    16390
# AS14.07    16045
# AS14.17    15826
# AS14.05    15745
# AS14.02    14581
# AS14.27    14575
# AS14.24    14430
# AS14.03    14425
# AS14.25    12589
# AS14.31    11889
# AS14.19    11397
# AS14.32    11193
# AS14.09    10886
# AS14.14     9286
# AS14.08     7902
# AS14.16     3982
# AS14.20     3620
# AS14.15     2848
# Name: id, dtype: int64

# %%
df.id.value_counts().plot.bar()

# for person in df.id.value_counts():
#     print (person)

# %%
df.time.unique()
# Out:
# array(['2014-02-26T13:00:00.000000000', '2014-02-26T15:00:00.000000000',
#        '2014-02-26T18:00:00.000000000', ...,
#        '2014-04-26T10:19:07.434000000', '2014-04-27T00:44:48.450000000',
#        '2014-04-07T18:25:14.036000000'], dtype='datetime64[ns]')

# %% [markdown]
# ## simple time series plots
#
# just some examples, not for actual use

# %%
# filter out a single user

df_filtered = df.query('id=="AS14.01"')
# filter out a single variable to plot

df_filtered = df_filtered.query('variable == "mood"')

# set the index to time to make things plottable? not sure why I can't do it otherwise but whatever 
df_filtered.index = df_filtered['time']


ts = pd.Series(df_filtered.value)
# .resample('D', how='mean').loc[df.index].fillna(method='ffill')



ploti = ts.plot()

# %%
df.id.unique()
# Out:
# array(['AS14.01', 'AS14.02', 'AS14.03', 'AS14.05', 'AS14.06', 'AS14.07',
#        'AS14.08', 'AS14.09', 'AS14.12', 'AS14.13', 'AS14.14', 'AS14.15',
#        'AS14.16', 'AS14.17', 'AS14.19', 'AS14.20', 'AS14.23', 'AS14.24',
#        'AS14.25', 'AS14.26', 'AS14.27', 'AS14.28', 'AS14.29', 'AS14.30',
#        'AS14.31', 'AS14.32', 'AS14.33'], dtype=object)

# %%
people = ["AS14.01", "AS14.23", "AS14.13"]
variable =  "mood"

temporary = df[(df.variable == variable) & (df.id.isin(people))]



temporary.pivot_table(index='time',columns='id',values='value').interpolate(method='linear').plot(figsize=(20,10), title="mood per person")

# %%
people = ["AS14.01"]

variables = ["mood", "circumplex.valence", "circumplex.arousal"]

temporary = df[(df.id.isin(people)) & df.variable.isin(variables)]

temporary.pivot_table(index='time',columns='variable',values='value').interpolate(method='linear').plot(figsize=(20,10), title="variables of AS14.01")

# %% [markdown]
# ## Aggregating data into days
#
# This part is very important. Since we only consider time in days it does not make sense to make things more complicated by having many datapoints per day. Naturally we lose information which might be important by doing this. For example, the amount of times the user 'checks' their phone might be indicative of nervousness. However, I don't want to make things complicated.

# %%
#  example of resampling just one mood for one person.

people = ["AS14.01"]

variables = ["mood"]


temporary = df[(df.id.isin(people)) & df.variable.isin(variables)]
temporary.set_index('time',inplace=True)
temporary_series = pd.Series(temporary.value)

temporary_series.resample('D').mean()
# Out:
# time
# 2014-02-26    6.250000
# 2014-02-27    6.333333
# 2014-02-28         NaN
# 2014-03-01         NaN
# 2014-03-02         NaN
# 2014-03-03         NaN
# 2014-03-04         NaN
# 2014-03-05         NaN
# 2014-03-06         NaN
# 2014-03-07         NaN
# 2014-03-08         NaN
# 2014-03-09         NaN
# 2014-03-10         NaN
# 2014-03-11         NaN
# 2014-03-12         NaN
# 2014-03-13         NaN
# 2014-03-14         NaN
# 2014-03-15         NaN
# 2014-03-16         NaN
# 2014-03-17         NaN
# 2014-03-18         NaN
# 2014-03-19         NaN
# 2014-03-20         NaN
# 2014-03-21    6.200000
# 2014-03-22    6.400000
# 2014-03-23    6.800000
# 2014-03-24    6.000000
# 2014-03-25    6.750000
# 2014-03-26    6.600000
# 2014-03-27    7.000000
#                 ...
# 2014-04-05    6.800000
# 2014-04-06    6.500000
# 2014-04-07    6.500000
# 2014-04-08    6.600000
# 2014-04-09    7.400000
# 2014-04-10    7.400000
# 2014-04-11    7.000000
# 2014-04-12    7.250000
# 2014-04-13    8.000000
# 2014-04-14    7.200000
# 2014-04-15    6.400000
# 2014-04-16    7.200000
# 2014-04-17    6.600000
# 2014-04-18    6.800000
# 2014-04-19    7.800000
# 2014-04-20    7.250000
# 2014-04-21    7.600000
# 2014-04-22    7.400000
# 2014-04-23    7.600000
# 2014-04-24    7.600000
# 2014-04-25    7.200000
# 2014-04-26    7.600000
# 2014-04-27    7.500000
# 2014-04-28    7.600000
# 2014-04-29    7.000000
# 2014-04-30    7.800000
# 2014-05-01    8.000000
# 2014-05-02    7.600000
# 2014-05-03    8.000000
# 2014-05-04    8.000000
# Freq: D, Name: value, Length: 68, dtype: float64

# %% [markdown]
# ## using multi-index to make hierarchical series data
#
# I am trying to learn how to manage the data properly so we can place it in the correct format ;)

# %% [markdown]
# First we make sure all the data is grouped by DAYS
# For this I stole a grouper function from stack overflow

# %%
# VERSIE 1

import pandas as pd

types = {'id':str, 'time':str, 'variable':str, 'value':float}
parse_dates = ['time']
df = pd.read_csv('dataset_mood_smartphone.csv', index_col=0, dtype=types, parse_dates=parse_dates)

df.set_index(['id', 'variable', 'time'], inplace=True)

def using_Grouper(df):
    level_values = df.index.get_level_values
    return (df.groupby([level_values(i) for i in [0,1]]
                       +[pd.Grouper(freq='D', level=-1)]).mean())

df_by_day = using_Grouper(df)
df_by_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 15522 entries, (AS14.01, activity, 2014-03-20 00:00:00) to (AS14.33, sms, 2014-05-29 00:00:00)
# Data columns (total 1 columns):
# value    15520 non-null float64
# dtypes: float64(1)
# memory usage: 168.2+ KB

# %%
# VERSIE 2

import pandas as pd

types = {'id':str, 'time':str, 'variable':str, 'value':float}
parse_dates = ['time']
df = pd.read_csv('dataset_mood_smartphone.csv', index_col=0, dtype=types, parse_dates=parse_dates)

df.set_index(['id', 'variable', 'time'], inplace=True)

def using_Grouper(df):
    level_values = df.index.get_level_values
    a = [level_values(i) for i in [0,1]]
    b = [pd.Grouper(freq='D', level='time')]
    c = [pd.Grouper(level='variable')]

    c = df.groupby(a+b)

#     d = c.mean()
    d = c.agg([np.sum, np.mean])

    return d

df_by_day = using_Grouper(df)

to_mean = ["mood", "circumplex.arousal", "circumplex.valence"]


df_by_day['value2'] = np.where(df_by_day.index.isin(to_mean, level='variable'), df_by_day['value']['mean'], df_by_day['value']['sum'])
# df_by_day.loc[("AS14.01", "mood")]
df_by_day.drop('value', axis=1, inplace=True)
df_by_day.rename(columns={'value2':'value'}, inplace=True)
df_by_day
# Out:
#                                 value
#
# id      variable time
# AS14.01 activity 2014-03-20  0.163095
#                  2014-03-21  3.083152
#                  2014-03-22  3.790084
#                  2014-03-23  2.141117
#                  2014-03-24  1.895065
#                  2014-03-25  2.360979
#                  2014-03-26  2.431400
#                  2014-03-27  3.509234
#                  2014-03-28  2.296753
#                  2014-03-29  1.636867
#                  2014-03-30  0.687302
#                  2014-03-31  1.692132
#                  2014-04-01  2.842638
#                  2014-04-02  2.445999
#                  2014-04-03  1.181723
#                  2014-04-04  3.040543
#                  2014-04-05  2.856055
#                  2014-04-06  1.545787
#                  2014-04-07  1.216095
#                  2014-04-08  1.807849
#                  2014-04-09  2.889219
#                  2014-04-10  1.895115
#                  2014-04-11  1.919669
#                  2014-04-12  1.733977
#                  2014-04-13  0.336512
#                  2014-04-14  2.013296
#                  2014-04-15  2.162692
#                  2014-04-16  2.786648
#                  2014-04-17  1.366029
#                  2014-04-18  2.256792
# ...                               ...
# AS14.33 sms      2014-03-25  1.000000
#                  2014-03-26  1.000000
#                  2014-03-29  3.000000
#                  2014-03-30  2.000000
#                  2014-04-02  1.000000
#                  2014-04-09  1.000000
#                  2014-04-11  1.000000
#                  2014-04-15  1.000000
#                  2014-04-16  1.000000
#                  2014-04-18  1.000000
#                  2014-04-24  3.000000
#                  2014-04-25  2.000000
#                  2014-04-26  4.000000
#                  2014-04-28  1.000000
#                  2014-04-29  1.000000
#                  2014-05-01  1.000000
#                  2014-05-02  3.000000
#                  2014-05-03  1.000000
#                  2014-05-04  1.000000
#                  2014-05-06  1.000000
#                  2014-05-07  1.000000
#                  2014-05-09  2.000000
#                  2014-05-15  2.000000
#                  2014-05-17  1.000000
#                  2014-05-23  1.000000
#                  2014-05-25  1.000000
#                  2014-05-26  3.000000
#                  2014-05-27  2.000000
#                  2014-05-28  1.000000
#                  2014-05-29  1.000000
#
# [15522 rows x 1 columns]

# %% [markdown]
# Now we create a multi-index. We set the hierarchy to be: ID -> Time -> variables: value
#
# However we see that there are many missing values. For example, if the user does not input "mood" for a day that value will not be displayed.

# %%
# df_by_day.reset_index()

# 

temper = df_by_day.reset_index()

temper.set_index(['id', 'time', 'variable'], inplace=True)
# temper.set_index(['id', 'variable', 'time'], inplace=True)

# temper.loc[("AS14.01", "2014-03-20")]
# temper = temper.loc[("AS14.01")].sort_index(level="time")
temper = temper.sort_index(level=["id", "time"])
temper
# temper.loc[("AS14.01")]
# Out:
#                                               value
# id      time       variable
# AS14.01 2014-02-17 call                    1.000000
#         2014-02-18 call                    1.000000
#         2014-02-19 call                    1.000000
#                    sms                     1.000000
#         2014-02-20 call                    1.000000
#                    sms                     1.000000
#         2014-02-21 sms                     1.000000
#         2014-02-22 call                    1.000000
#                    sms                     1.000000
#         2014-02-25 call                    1.000000
#         2014-02-26 call                    1.000000
#                    circumplex.arousal     -0.250000
#                    circumplex.valence      0.750000
#                    mood                    6.250000
#                    sms                     1.000000
#         2014-02-27 circumplex.arousal      0.000000
#                    circumplex.valence      0.333333
#                    mood                    6.333333
#         2014-02-28 call                    1.000000
#         2014-03-01 sms                     1.000000
#         2014-03-03 call                    1.000000
#         2014-03-05 call                    1.000000
#         2014-03-06 call                    1.000000
#         2014-03-07 call                    1.000000
#         2014-03-10 call                    1.000000
#         2014-03-11 call                    1.000000
#         2014-03-12 call                    1.000000
#                    sms                     1.000000
#         2014-03-13 call                    1.000000
#         2014-03-14 call                    1.000000
# ...                                             ...
# AS14.33 2014-05-29 appCat.builtin          6.452161
#                    appCat.communication   54.388125
#                    appCat.entertainment   68.369000
#                    appCat.other            9.734000
#                    appCat.social         198.880222
#                    appCat.travel           0.939000
#                    appCat.utilities        1.599500
#                    call                    1.000000
#                    circumplex.arousal     -1.333333
#                    circumplex.valence      1.000000
#                    mood                    7.000000
#                    screen                118.978033
#                    sms                     1.000000
#         2014-05-30 activity                0.192901
#                    appCat.builtin         14.776845
#                    appCat.communication   46.412278
#                    appCat.entertainment   37.174286
#                    appCat.other           10.522000
#                    appCat.social          75.390690
#                    appCat.travel          37.594571
#                    appCat.unknown          2.690667
#                    appCat.utilities       15.521667
#                    call                    1.000000
#                    circumplex.arousal     -0.800000
#                    circumplex.valence     -0.400000
#                    mood                    6.800000
#                    screen                 86.342245
#         2014-05-31 circumplex.arousal     -2.000000
#                    circumplex.valence      1.000000
#                    mood                    7.000000
#
# [15522 rows x 1 columns]

# %% [markdown]
# ## handling missing missing values
#
# To create data with added missing values (if we wanted for example to have evenly sized vectors for each day) we would have to make an empty multi-index as above with all possible combinations and set all of their values to NaN.
#
# I follow these instructions to do this: https://medium.com/when-i-work-data/using-pandas-multiindex-from-product-to-fill-in-missing-data-43c3cfe9cf39

# %%
from datetime import datetime
import numpy as np
# both of these should produce the same date-range
date_range = pd.date_range(
    start="2014-02-17",
    end="2014-06-9",
    freq='D'
)

date_range = temper.index.unique(level='time')
unique_id = temper.index.unique(level='id')
unique_variables = temper.index.unique(level='variable')

blank_dataframe = (
    pd.MultiIndex
    .from_product(
        iterables=[unique_id, date_range, unique_variables],
        names=['id', 'time', 'variable']
    )
)
blank_dataframe.values[:5]
# Out:
# array([('AS14.01', Timestamp('2014-02-17 00:00:00'), 'call'),
#        ('AS14.01', Timestamp('2014-02-17 00:00:00'), 'sms'),
#        ('AS14.01', Timestamp('2014-02-17 00:00:00'), 'circumplex.arousal'),
#        ('AS14.01', Timestamp('2014-02-17 00:00:00'), 'circumplex.valence'),
#        ('AS14.01', Timestamp('2014-02-17 00:00:00'), 'mood')],
#       dtype=object)

# %%
temper = temper.reindex(blank_dataframe)

temper.head()
# Out:
#                                        value
# id      time       variable
# AS14.01 2014-02-17 call                  1.0
#                    sms                   NaN
#                    circumplex.arousal    NaN
#                    circumplex.valence    NaN
#                    mood                  NaN

# %%
temper.index.unique(level='id')
# Out:
# Index(['AS14.01', 'AS14.02', 'AS14.03', 'AS14.05', 'AS14.06', 'AS14.07',
#        'AS14.08', 'AS14.09', 'AS14.12', 'AS14.13', 'AS14.14', 'AS14.15',
#        'AS14.16', 'AS14.17', 'AS14.19', 'AS14.20', 'AS14.23', 'AS14.24',
#        'AS14.25', 'AS14.26', 'AS14.27', 'AS14.28', 'AS14.29', 'AS14.30',
#        'AS14.31', 'AS14.32', 'AS14.33'],
#       dtype='object', name='id')

# %% [markdown]
# ## Creating dataset for actual model use
#
# Once we have properly formatted the data into users, days, variables we can create labeled data. The data format is quite simple (see figure 2 of the assignment). Each datapoint will contain 5 + 1 days. The last day will be the label/prediction. Naturally, we need to keep missing data in mind. How do we go about this? Interpolate? Throw away?
#
# The format is also important. I think the best is to make a tuple (Matrix, mood). The matrix will be 5 column vectors representing the 5 days. Each vector will contain the variables for that day. The second value in the tuple will be the average mood for the subsequent day and will also serve as the arget/label for our supervised data.

# %%
n_days = 5
a = [13, 2, 3, 4, 5,45]
for ibin in [range(i, i+n_days) for i in range(len(a)-n_days+1)]:
    for i in ibin:
        print(a[i])
    print(" sdfds" )
# Out:
# 13
# 2
# 3
# 4
# 5
#  sdfds
# 2
# 3
# 4
# 5
# 45
#  sdfds

# %%
def create_instance_dataset(dataset):
    n_days = 3
    instance_dataset = []
    for person in dataset.index.unique(level='id'):
        series = dataset.loc[(person, slice(None))].unstack()
        days_count = len(series)
        series = series.transpose()
        for i in range(days_count-n_days):
            target_day = series.columns[i+n_days]
            target = series.loc[('value', 'mood'), target_day]
            interval = series.loc[:, series.columns[i:i+n_days]]
            instance_dataset.append((person, target_day, interval, target))
    return instance_dataset
create_instance_dataset(temper)
# Out:
# [('AS14.01',
#   Timestamp('2014-02-20 00:00:00'),
#   time                        2014-02-17  2014-02-18  2014-02-19
#         variable
#   value activity                     NaN         NaN         NaN
#         appCat.builtin               NaN         NaN         NaN
#         appCat.communication         NaN         NaN         NaN
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN         NaN
#         appCat.social                NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN
#         appCat.weather               NaN         NaN         NaN
#         call                         1.0         1.0         1.0
#         circumplex.arousal           NaN         NaN         NaN
#         circumplex.valence           NaN         NaN         NaN
#         mood                         NaN         NaN         NaN
#         screen                       NaN         NaN         NaN
#         sms                          NaN         NaN         1.0,
#   nan),
#  ('AS14.01',
#   Timestamp('2014-02-21 00:00:00'),
#   time                        2014-02-18  2014-02-19  2014-02-20
#         variable
#   value activity                     NaN         NaN         NaN
#         appCat.builtin               NaN         NaN         NaN
#         appCat.communication         NaN         NaN         NaN
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN         NaN
#         appCat.social                NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN
#         appCat.weather               NaN         NaN         NaN
#         call                         1.0         1.0         1.0
#         circumplex.arousal           NaN         NaN         NaN
#         circumplex.valence           NaN         NaN         NaN
#         mood                         NaN         NaN         NaN
#         screen                       NaN         NaN         NaN
#         sms                          NaN         1.0         1.0,
#   nan),
#  ('AS14.01',
#   Timestamp('2014-02-22 00:00:00'),
#   time                        2014-02-19  2014-02-20  2014-02-21
#         variable
#   value activity                     NaN         NaN         NaN
#         appCat.builtin               NaN         NaN         NaN
#         appCat.communication         NaN         NaN         NaN
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN         NaN
#         appCat.social                NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN
#         appCat.weather               NaN         NaN         NaN
#         call                         1.0         1.0         NaN
#         circumplex.arousal           NaN         NaN         NaN
#         circumplex.valence           NaN         NaN         NaN
#         mood                         NaN         NaN         NaN
#         screen                       NaN         NaN         NaN
#         sms                          1.0         1.0         1.0,
#   nan),
#  ('AS14.01',
#   Timestamp('2014-02-25 00:00:00'),
#   time                        2014-02-20  2014-02-21  2014-02-22
#         variable
#   value activity                     NaN         NaN         NaN
#         appCat.builtin               NaN         NaN         NaN
#         appCat.communication         NaN         NaN         NaN
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN         NaN
#         appCat.social                NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN
#         appCat.weather               NaN         NaN         NaN
#         call                         1.0         NaN         1.0
#         circumplex.arousal           NaN         NaN         NaN
#         circumplex.valence           NaN         NaN         NaN
#         mood                         NaN         NaN         NaN
#         screen                       NaN         NaN         NaN
#         sms                          1.0         1.0         1.0,
#   nan),
#  ('AS14.01',
#   Timestamp('2014-02-26 00:00:00'),
#   time                        2014-02-21  2014-02-22  2014-02-25
#         variable
#   value activity                     NaN         NaN         NaN
#         appCat.builtin               NaN         NaN         NaN
#         appCat.communication         NaN         NaN         NaN
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN         NaN
#         appCat.social                NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN
#         appCat.weather               NaN         NaN         NaN
#         call                         NaN         1.0         1.0
#         circumplex.arousal           NaN         NaN         NaN
#         circumplex.valence           NaN         NaN         NaN
#         mood                         NaN         NaN         NaN
#         screen                       NaN         NaN         NaN
#         sms                          1.0         1.0         NaN,
#   6.25),
#  ('AS14.01',
#   Timestamp('2014-02-27 00:00:00'),
#   time                        2014-02-22  2014-02-25  2014-02-26
#         variable
#   value activity                     NaN         NaN         NaN
#         appCat.builtin               NaN         NaN         NaN
#         appCat.communication         NaN         NaN         NaN
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN         NaN
#         appCat.social                NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN
#         appCat.weather               NaN         NaN         NaN
#         call                         1.0         1.0        1.00
#         circumplex.arousal           NaN         NaN       -0.25
#         circumplex.valence           NaN         NaN        0.75
#         mood                         NaN         NaN        6.25
#         screen                       NaN         NaN         NaN
#         sms                          1.0         NaN        1.00,
#   6.333333333333333),
#  ('AS14.01',
#   Timestamp('2014-02-28 00:00:00'),
#   time                        2014-02-25  2014-02-26  2014-02-27
#         variable
#   value activity                     NaN         NaN         NaN
#         appCat.builtin               NaN         NaN         NaN
#         appCat.communication         NaN         NaN         NaN
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN         NaN
#         appCat.social                NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN
#         appCat.weather               NaN         NaN         NaN
#         call                         1.0        1.00         NaN
#         circumplex.arousal           NaN       -0.25    0.000000
#         circumplex.valence           NaN        0.75    0.333333
#         mood                         NaN        6.25    6.333333
#         screen                       NaN         NaN         NaN
#         sms                          NaN        1.00         NaN,
#   nan),
#  ('AS14.01',
#   Timestamp('2014-03-01 00:00:00'),
#   time                        2014-02-26  2014-02-27  2014-02-28
#         variable
#   value activity                     NaN         NaN         NaN
#         appCat.builtin               NaN         NaN         NaN
#         appCat.communication         NaN         NaN         NaN
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN         NaN
#         appCat.social                NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN
#         appCat.weather               NaN         NaN         NaN
#         call                        1.00         NaN         1.0
#         circumplex.arousal         -0.25    0.000000         NaN
#         circumplex.valence          0.75    0.333333         NaN
#         mood                        6.25    6.333333         NaN
#         screen                       NaN         NaN         NaN
#         sms                         1.00         NaN         NaN,
#   nan),
#  ('AS14.01',
#   Timestamp('2014-03-03 00:00:00'),
#   time                        2014-02-27  2014-02-28  2014-03-01
#         variable
#   value activity                     NaN         NaN         NaN
#         appCat.builtin               NaN         NaN         NaN
#         appCat.communication         NaN         NaN         NaN
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN         NaN
#         appCat.social                NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN
#         appCat.weather               NaN         NaN         NaN
#         call                         NaN         1.0         NaN
#         circumplex.arousal      0.000000         NaN         NaN
#         circumplex.valence      0.333333         NaN         NaN
#         mood                    6.333333         NaN         NaN
#         screen                       NaN         NaN         NaN
#         sms                          NaN         NaN         1.0,
#   nan),
#  ('AS14.01',
#   Timestamp('2014-03-05 00:00:00'),
#   time                        2014-02-28  2014-03-01  2014-03-03
#         variable
#   value activity                     NaN         NaN         NaN
#         appCat.builtin               NaN         NaN         NaN
#         appCat.communication         NaN         NaN         NaN
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN         NaN
#         appCat.social                NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN
#         appCat.weather               NaN         NaN         NaN
#         call                         1.0         NaN         1.0
#         circumplex.arousal           NaN         NaN         NaN
#         circumplex.valence           NaN         NaN         NaN
#         mood                         NaN         NaN         NaN
#         screen                       NaN         NaN         NaN
#         sms                          NaN         1.0         NaN,
#   nan),
#  ('AS14.01',
#   Timestamp('2014-03-06 00:00:00'),
#   time                        2014-03-01  2014-03-03  2014-03-05
#         variable
#   value activity                     NaN         NaN         NaN
#         appCat.builtin               NaN         NaN         NaN
#         appCat.communication         NaN         NaN         NaN
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN         NaN
#         appCat.social                NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN
#         appCat.weather               NaN         NaN         NaN
#         call                         NaN         1.0         1.0
#         circumplex.arousal           NaN         NaN         NaN
#         circumplex.valence           NaN         NaN         NaN
#         mood                         NaN         NaN         NaN
#         screen                       NaN         NaN         NaN
#         sms                          1.0         NaN         NaN,
#   nan),
#  ('AS14.01',
#   Timestamp('2014-03-07 00:00:00'),
#   time                        2014-03-03  2014-03-05  2014-03-06
#         variable
#   value activity                     NaN         NaN         NaN
#         appCat.builtin               NaN         NaN         NaN
#         appCat.communication         NaN         NaN         NaN
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN         NaN
#         appCat.social                NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN
#         appCat.weather               NaN         NaN         NaN
#         call                         1.0         1.0         1.0
#         circumplex.arousal           NaN         NaN         NaN
#         circumplex.valence           NaN         NaN         NaN
#         mood                         NaN         NaN         NaN
#         screen                       NaN         NaN         NaN
#         sms                          NaN         NaN         NaN,
#   nan),
#  ('AS14.01',
#   Timestamp('2014-03-10 00:00:00'),
#   time                        2014-03-05  2014-03-06  2014-03-07
#         variable
#   value activity                     NaN         NaN         NaN
#         appCat.builtin               NaN         NaN         NaN
#         appCat.communication         NaN         NaN         NaN
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN         NaN
#         appCat.social                NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN
#         appCat.weather               NaN         NaN         NaN
#         call                         1.0         1.0         1.0
#         circumplex.arousal           NaN         NaN         NaN
#         circumplex.valence           NaN         NaN         NaN
#         mood                         NaN         NaN         NaN
#         screen                       NaN         NaN         NaN
#         sms                          NaN         NaN         NaN,
#   nan),
#  ('AS14.01',
#   Timestamp('2014-03-11 00:00:00'),
#   time                        2014-03-06  2014-03-07  2014-03-10
#         variable
#   value activity                     NaN         NaN         NaN
#         appCat.builtin               NaN         NaN         NaN
#         appCat.communication         NaN         NaN         NaN
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN         NaN
#         appCat.social                NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN
#         appCat.weather               NaN         NaN         NaN
#         call                         1.0         1.0         1.0
#         circumplex.arousal           NaN         NaN         NaN
#         circumplex.valence           NaN         NaN         NaN
#         mood                         NaN         NaN         NaN
#         screen                       NaN         NaN         NaN
#         sms                          NaN         NaN         NaN,
#   nan),
#  ('AS14.01',
#   Timestamp('2014-03-12 00:00:00'),
#   time                        2014-03-07  2014-03-10  2014-03-11
#         variable
#   value activity                     NaN         NaN         NaN
#         appCat.builtin               NaN         NaN         NaN
#         appCat.communication         NaN         NaN         NaN
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN         NaN
#         appCat.social                NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN
#         appCat.weather               NaN         NaN         NaN
#         call                         1.0         1.0         1.0
#         circumplex.arousal           NaN         NaN         NaN
#         circumplex.valence           NaN         NaN         NaN
#         mood                         NaN         NaN         NaN
#         screen                       NaN         NaN         NaN
#         sms                          NaN         NaN         NaN,
#   nan),
#  ('AS14.01',
#   Timestamp('2014-03-13 00:00:00'),
#   time                        2014-03-10  2014-03-11  2014-03-12
#         variable
#   value activity                     NaN         NaN         NaN
#         appCat.builtin               NaN         NaN         NaN
#         appCat.communication         NaN         NaN         NaN
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN         NaN
#         appCat.social                NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN
#         appCat.weather               NaN         NaN         NaN
#         call                         1.0         1.0         1.0
#         circumplex.arousal           NaN         NaN         NaN
#         circumplex.valence           NaN         NaN         NaN
#         mood                         NaN         NaN         NaN
#         screen                       NaN         NaN         NaN
#         sms                          NaN         NaN         1.0,
#   nan),
#  ('AS14.01',
#   Timestamp('2014-03-14 00:00:00'),
#   time                        2014-03-11  2014-03-12  2014-03-13
#         variable
#   value activity                     NaN         NaN         NaN
#         appCat.builtin               NaN         NaN         NaN
#         appCat.communication         NaN         NaN         NaN
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN         NaN
#         appCat.social                NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN
#         appCat.weather               NaN         NaN         NaN
#         call                         1.0         1.0         1.0
#         circumplex.arousal           NaN         NaN         NaN
#         circumplex.valence           NaN         NaN         NaN
#         mood                         NaN         NaN         NaN
#         screen                       NaN         NaN         NaN
#         sms                          NaN         1.0         NaN,
#   nan),
#  ('AS14.01',
#   Timestamp('2014-03-15 00:00:00'),
#   time                        2014-03-12  2014-03-13  2014-03-14
#         variable
#   value activity                     NaN         NaN         NaN
#         appCat.builtin               NaN         NaN         NaN
#         appCat.communication         NaN         NaN         NaN
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN         NaN
#         appCat.social                NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN
#         appCat.weather               NaN         NaN         NaN
#         call                         1.0         1.0         1.0
#         circumplex.arousal           NaN         NaN         NaN
#         circumplex.valence           NaN         NaN         NaN
#         mood                         NaN         NaN         NaN
#         screen                       NaN         NaN         NaN
#         sms                          1.0         NaN         1.0,
#   nan),
#  ('AS14.01',
#   Timestamp('2014-03-16 00:00:00'),
#   time                        2014-03-13  2014-03-14  2014-03-15
#         variable
#   value activity                     NaN         NaN         NaN
#         appCat.builtin               NaN         NaN         NaN
#         appCat.communication         NaN         NaN         NaN
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN         NaN
#         appCat.social                NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN
#         appCat.weather               NaN         NaN         NaN
#         call                         1.0         1.0         NaN
#         circumplex.arousal           NaN         NaN         NaN
#         circumplex.valence           NaN         NaN         NaN
#         mood                         NaN         NaN         NaN
#         screen                       NaN         NaN         NaN
#         sms                          NaN         1.0         1.0,
#   nan),
#  ('AS14.01',
#   Timestamp('2014-03-17 00:00:00'),
#   time                        2014-03-14  2014-03-15  2014-03-16
#         variable
#   value activity                     NaN         NaN         NaN
#         appCat.builtin               NaN         NaN         NaN
#         appCat.communication         NaN         NaN         NaN
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN         NaN
#         appCat.social                NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN
#         appCat.weather               NaN         NaN         NaN
#         call                         1.0         NaN         NaN
#         circumplex.arousal           NaN         NaN         NaN
#         circumplex.valence           NaN         NaN         NaN
#         mood                         NaN         NaN         NaN
#         screen                       NaN         NaN         NaN
#         sms                          1.0         1.0         1.0,
#   nan),
#  ('AS14.01',
#   Timestamp('2014-03-18 00:00:00'),
#   time                        2014-03-15  2014-03-16  2014-03-17
#         variable
#   value activity                     NaN         NaN         NaN
#         appCat.builtin               NaN         NaN         NaN
#         appCat.communication         NaN         NaN         NaN
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN         NaN
#         appCat.social                NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN
#         appCat.weather               NaN         NaN         NaN
#         call                         NaN         NaN         NaN
#         circumplex.arousal           NaN         NaN         NaN
#         circumplex.valence           NaN         NaN         NaN
#         mood                         NaN         NaN         NaN
#         screen                       NaN         NaN         NaN
#         sms                          1.0         1.0         1.0,
#   nan),
#  ('AS14.01',
#   Timestamp('2014-03-19 00:00:00'),
#   time                        2014-03-16  2014-03-17  2014-03-18
#         variable
#   value activity                     NaN         NaN         NaN
#         appCat.builtin               NaN         NaN         NaN
#         appCat.communication         NaN         NaN         NaN
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN         NaN
#         appCat.social                NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN
#         appCat.weather               NaN         NaN         NaN
#         call                         NaN         NaN         1.0
#         circumplex.arousal           NaN         NaN         NaN
#         circumplex.valence           NaN         NaN         NaN
#         mood                         NaN         NaN         NaN
#         screen                       NaN         NaN         NaN
#         sms                          1.0         1.0         1.0,
#   nan),
#  ('AS14.01',
#   Timestamp('2014-03-20 00:00:00'),
#   time                        2014-03-17  2014-03-18  2014-03-19
#         variable
#   value activity                     NaN         NaN         NaN
#         appCat.builtin               NaN         NaN         NaN
#         appCat.communication         NaN         NaN         NaN
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN         NaN
#         appCat.social                NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN
#         appCat.weather               NaN         NaN         NaN
#         call                         NaN         1.0         1.0
#         circumplex.arousal           NaN         NaN         NaN
#         circumplex.valence           NaN         NaN         NaN
#         mood                         NaN         NaN         NaN
#         screen                       NaN         NaN         NaN
#         sms                          1.0         1.0         NaN,
#   nan),
#  ('AS14.01',
#   Timestamp('2014-03-21 00:00:00'),
#   time                        2014-03-18  2014-03-19  2014-03-20
#         variable
#   value activity                     NaN         NaN    0.081548
#         appCat.builtin               NaN         NaN    5.928071
#         appCat.communication         NaN         NaN   58.600784
#         appCat.entertainment         NaN         NaN   58.476000
#         appCat.finance               NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other                 NaN         NaN    5.672500
#         appCat.social                NaN         NaN   73.430091
#         appCat.travel                NaN         NaN         NaN
#         appCat.unknown               NaN         NaN   45.173000
#         appCat.utilities             NaN         NaN   10.537000
#         appCat.weather               NaN         NaN         NaN
#         call                         1.0         1.0    1.000000
#         circumplex.arousal           NaN         NaN         NaN
#         circumplex.valence           NaN         NaN         NaN
#         mood                         NaN         NaN         NaN
#         screen                       NaN         NaN  252.882667
#         sms                          1.0         NaN         NaN,
#   6.2),
#  ('AS14.01',
#   Timestamp('2014-03-22 00:00:00'),
#   time                        2014-03-19  2014-03-20  2014-03-21
#         variable
#   value activity                     NaN    0.081548    0.134050
#         appCat.builtin               NaN    5.928071   14.269173
#         appCat.communication         NaN   58.600784   55.095526
#         appCat.entertainment         NaN   58.476000   53.024000
#         appCat.finance               NaN         NaN    6.193000
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN   57.402000
#         appCat.other                 NaN    5.672500   29.968875
#         appCat.social                NaN   73.430091   75.141667
#         appCat.travel                NaN         NaN   70.418846
#         appCat.unknown               NaN   45.173000         NaN
#         appCat.utilities             NaN   10.537000   23.029000
#         appCat.weather               NaN         NaN         NaN
#         call                         1.0    1.000000    1.000000
#         circumplex.arousal           NaN         NaN    0.200000
#         circumplex.valence           NaN         NaN    0.200000
#         mood                         NaN         NaN    6.200000
#         screen                       NaN  252.882667  153.665872
#         sms                          NaN         NaN         NaN,
#   6.4),
#  ('AS14.01',
#   Timestamp('2014-03-23 00:00:00'),
#   time                        2014-03-20  2014-03-21  2014-03-22
#         variable
#   value activity                0.081548    0.134050    0.236880
#         appCat.builtin          5.928071   14.269173    7.781160
#         appCat.communication   58.600784   55.095526   51.697063
#         appCat.entertainment   58.476000   53.024000   46.662000
#         appCat.finance               NaN    6.193000    7.025333
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN   57.402000         NaN
#         appCat.other            5.672500   29.968875   14.020429
#         appCat.social          73.430091   75.141667   36.636000
#         appCat.travel                NaN   70.418846   37.305000
#         appCat.unknown         45.173000         NaN         NaN
#         appCat.utilities       10.537000   23.029000   39.207000
#         appCat.weather               NaN         NaN         NaN
#         call                    1.000000    1.000000    1.000000
#         circumplex.arousal           NaN    0.200000    0.600000
#         circumplex.valence           NaN    0.200000    0.500000
#         mood                         NaN    6.200000    6.400000
#         screen                252.882667  153.665872   47.613651
#         sms                          NaN         NaN    1.000000,
#   6.8),
#  ('AS14.01',
#   Timestamp('2014-03-24 00:00:00'),
#   time                        2014-03-21  2014-03-22  2014-03-23
#         variable
#   value activity                0.134050    0.236880    0.142741
#         appCat.builtin         14.269173    7.781160   12.134396
#         appCat.communication   55.095526   51.697063   53.442031
#         appCat.entertainment   53.024000   46.662000   31.448667
#         appCat.finance          6.193000    7.025333   10.850750
#         appCat.game                  NaN         NaN         NaN
#         appCat.office          57.402000         NaN         NaN
#         appCat.other           29.968875   14.020429   12.137167
#         appCat.social          75.141667   36.636000   50.046611
#         appCat.travel          70.418846   37.305000         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities       23.029000   39.207000   30.086000
#         appCat.weather               NaN         NaN   30.386000
#         call                    1.000000    1.000000         NaN
#         circumplex.arousal      0.200000    0.600000    0.200000
#         circumplex.valence      0.200000    0.500000    0.800000
#         mood                    6.200000    6.400000    6.800000
#         screen                153.665872   47.613651   67.067644
#         sms                          NaN    1.000000         NaN,
#   6.0),
#  ('AS14.01',
#   Timestamp('2014-03-25 00:00:00'),
#   time                        2014-03-22  2014-03-23  2014-03-24
#         variable
#   value activity                0.236880    0.142741    0.078961
#         appCat.builtin          7.781160   12.134396    4.982506
#         appCat.communication   51.697063   53.442031   47.541687
#         appCat.entertainment   46.662000   31.448667  122.121375
#         appCat.finance          7.025333   10.850750    5.684333
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN    3.010000
#         appCat.other           14.020429   12.137167   11.093000
#         appCat.social          36.636000   50.046611   74.968047
#         appCat.travel          37.305000         NaN   83.961000
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities       39.207000   30.086000   89.366000
#         appCat.weather               NaN   30.386000         NaN
#         call                    1.000000         NaN    1.000000
#         circumplex.arousal      0.600000    0.200000    0.800000
#         circumplex.valence      0.500000    0.800000    0.000000
#         mood                    6.400000    6.800000    6.000000
#         screen                 47.613651   67.067644   76.772199
#         sms                     1.000000         NaN         NaN,
#   6.75),
#  ('AS14.01',
#   Timestamp('2014-03-26 00:00:00'),
#   time                        2014-03-23  2014-03-24  2014-03-25
#         variable
#   value activity                0.142741    0.078961    0.098374
#         appCat.builtin         12.134396    4.982506   10.026874
#         appCat.communication   53.442031   47.541687   69.437507
#         appCat.entertainment   31.448667  122.121375   34.103000
#         appCat.finance         10.850750    5.684333   10.763500
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN    3.010000         NaN
#         appCat.other           12.137167   11.093000   29.803167
#         appCat.social          50.046611   74.968047   68.552536
#         appCat.travel                NaN   83.961000         NaN
#         appCat.unknown               NaN         NaN   29.402875
#         appCat.utilities       30.086000   89.366000   22.289300
#         appCat.weather         30.386000         NaN         NaN
#         call                         NaN    1.000000         NaN
#         circumplex.arousal      0.200000    0.800000    0.500000
#         circumplex.valence      0.800000    0.000000    0.500000
#         mood                    6.800000    6.000000    6.750000
#         screen                 67.067644   76.772199  169.097283
#         sms                          NaN         NaN    1.000000,
#   6.6),
#  ('AS14.01',
#   Timestamp('2014-03-27 00:00:00'),
#   time                        2014-03-24  2014-03-25  2014-03-26
#         variable
#   value activity                0.078961    0.098374    0.101308
#         appCat.builtin          4.982506   10.026874    8.460123
#         appCat.communication   47.541687   69.437507   47.061534
#         appCat.entertainment  122.121375   34.103000  130.068429
#         appCat.finance          5.684333   10.763500    8.721833
#         appCat.game                  NaN         NaN         NaN
#         appCat.office           3.010000         NaN         NaN
#         appCat.other           11.093000   29.803167   16.249667
#         appCat.social          74.968047   68.552536  124.109703
#         appCat.travel          83.961000         NaN         NaN
#         appCat.unknown               NaN   29.402875         NaN
#         appCat.utilities       89.366000   22.289300   33.365000
#         appCat.weather               NaN         NaN         NaN
#         call                    1.000000         NaN         NaN
#         circumplex.arousal      0.800000    0.500000   -0.200000
#         circumplex.valence      0.000000    0.500000    0.600000
#         mood                    6.000000    6.750000    6.600000
#         screen                 76.772199  169.097283   94.389661
#         sms                          NaN    1.000000         NaN,
#   7.0),
#  ('AS14.01',
#   Timestamp('2014-03-28 00:00:00'),
#   time                        2014-03-25  2014-03-26  2014-03-27
#         variable
#   value activity                0.098374    0.101308    0.159511
#         appCat.builtin         10.026874    8.460123    7.982643
#         appCat.communication   69.437507   47.061534   43.353200
#         appCat.entertainment   34.103000  130.068429   71.037667
#         appCat.finance         10.763500    8.721833   14.073000
#         appCat.game                  NaN         NaN         NaN
#         appCat.office                NaN         NaN   15.204250
#         appCat.other           29.803167   16.249667    9.755333
#         appCat.social          68.552536  124.109703   71.952385
#         appCat.travel                NaN         NaN   23.657000
#         appCat.unknown         29.402875         NaN         NaN
#         appCat.utilities       22.289300   33.365000   16.275364
#         appCat.weather               NaN         NaN         NaN
#         call                         NaN         NaN    1.000000
#         circumplex.arousal      0.500000   -0.200000    0.200000
#         circumplex.valence      0.500000    0.600000    0.800000
#         mood                    6.750000    6.600000    7.000000
#         screen                169.097283   94.389661  129.201111
#         sms                     1.000000         NaN    1.000000,
#   6.4),
#  ('AS14.01',
#   Timestamp('2014-03-29 00:00:00'),
#   time                        2014-03-26  2014-03-27  2014-03-28
#         variable
#   value activity                0.101308    0.159511    0.095698
#         appCat.builtin          8.460123    7.982643   81.149960
#         appCat.communication   47.061534   43.353200   24.078694
#         appCat.entertainment  130.068429   71.037667   91.400273
#         appCat.finance          8.721833   14.073000   12.738000
#         appCat.game                  NaN         NaN  116.518000
#         appCat.office                NaN   15.204250         NaN
#         appCat.other           16.249667    9.755333   37.658500
#         appCat.social         124.109703   71.952385   25.637050
#         appCat.travel                NaN   23.657000   59.632053
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities       33.365000   16.275364   30.171700
#         appCat.weather               NaN         NaN         NaN
#         call                         NaN    1.000000    1.000000
#         circumplex.arousal     -0.200000    0.200000   -0.600000
#         circumplex.valence      0.600000    0.800000    0.600000
#         mood                    6.600000    7.000000    6.400000
#         screen                 94.389661  129.201111   55.948739
#         sms                          NaN    1.000000         NaN,
#   8.0),
#  ('AS14.01',
#   Timestamp('2014-03-30 00:00:00'),
#   time                        2014-03-27  2014-03-28  2014-03-29
#         variable
#   value activity                0.159511    0.095698    0.068203
#         appCat.builtin          7.982643   81.149960   23.525663
#         appCat.communication   43.353200   24.078694   47.731439
#         appCat.entertainment   71.037667   91.400273  108.495267
#         appCat.finance         14.073000   12.738000         NaN
#         appCat.game                  NaN  116.518000         NaN
#         appCat.office          15.204250         NaN         NaN
#         appCat.other            9.755333   37.658500   24.227714
#         appCat.social          71.952385   25.637050   59.111000
#         appCat.travel          23.657000   59.632053   17.478333
#         appCat.unknown               NaN         NaN         NaN
#         appCat.utilities       16.275364   30.171700   25.026542
#         appCat.weather               NaN         NaN         NaN
#         call                    1.000000    1.000000    1.000000
#         circumplex.arousal      0.200000   -0.600000    0.200000
#         circumplex.valence      0.800000    0.600000    1.000000
#         mood                    7.000000    6.400000    8.000000
#         screen                129.201111   55.948739  130.040969
#         sms                     1.000000         NaN    1.000000,
#   7.5),
#  ('AS14.01',
#   Timestamp('2014-03-31 00:00:00'),
#   time                        2014-03-28  2014-03-29  2014-03-30
#         variable
#   value activity                0.095698    0.068203    0.049093
#         appCat.builtin         81.149960   23.525663    7.818208
#         appCat.communication   24.078694   47.731439   61.833571
#         appCat.entertainment   91.400273  108.495267  170.630778
#         appCat.finance         12.738000         NaN         NaN
#         appCat.game           116.518000         NaN         NaN
#         appCat.office                NaN         NaN         NaN
#         appCat.other           37.658500   24.227714   12.333833
#         appCat.social          25.637050   59.111000   55.895000
#         appCat.travel          59.632053   17.478333         NaN
#         appCat.unknown               NaN         NaN   33.238500
#         appCat.utilities       30.171700   25.026542   38.296000
#         appCat.weather               NaN         NaN         NaN
# ...
#   7.25),
#  ('AS14.19',
#   Timestamp('2014-04-07 00:00:00'),
#   time                        2014-04-04  2014-04-05  2014-04-06
#         variable
#   value call                    1.000000    1.000000    1.000000
#         sms                          NaN         NaN    1.000000
#         activity                0.157021    0.135956    0.094224
#         appCat.builtin         12.153017   10.210825   10.325473
#         appCat.communication   22.017469   24.762705   26.745403
#         appCat.other           27.957000   13.076400    9.855400
#         appCat.social          43.881200   53.370000         NaN
#         circumplex.arousal     -0.200000   -0.600000   -1.250000
#         circumplex.valence      0.400000    1.200000    1.000000
#         mood                    7.000000    8.000000    7.250000
#         screen                 38.718961   38.174552   39.241937
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.game                  NaN   60.163667         NaN
#         appCat.utilities             NaN         NaN         NaN,
#   6.6),
#  ('AS14.19',
#   Timestamp('2014-04-08 00:00:00'),
#   time                        2014-04-05  2014-04-06  2014-04-07
#         variable
#   value call                    1.000000    1.000000    1.000000
#         sms                          NaN    1.000000         NaN
#         activity                0.135956    0.094224    0.183435
#         appCat.builtin         10.210825   10.325473   11.675891
#         appCat.communication   24.762705   26.745403   31.532337
#         appCat.other           13.076400    9.855400   12.716600
#         appCat.social          53.370000         NaN   71.526667
#         circumplex.arousal     -0.600000   -1.250000   -1.000000
#         circumplex.valence      1.200000    1.000000    0.600000
#         mood                    8.000000    7.250000    6.600000
#         screen                 38.174552   39.241937   28.834902
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.game            60.163667         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN,
#   6.8),
#  ('AS14.19',
#   Timestamp('2014-04-09 00:00:00'),
#   time                        2014-04-06  2014-04-07  2014-04-08
#         variable
#   value call                    1.000000    1.000000    1.000000
#         sms                     1.000000         NaN    1.000000
#         activity                0.094224    0.183435    0.089063
#         appCat.builtin         10.325473   11.675891    9.750275
#         appCat.communication   26.745403   31.532337   26.370836
#         appCat.other            9.855400   12.716600    7.879000
#         appCat.social                NaN   71.526667         NaN
#         circumplex.arousal     -1.250000   -1.000000   -0.400000
#         circumplex.valence      1.000000    0.600000    1.000000
#         mood                    7.250000    6.600000    6.800000
#         screen                 39.241937   28.834902   30.887798
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.utilities             NaN         NaN   13.335500,
#   7.2),
#  ('AS14.19',
#   Timestamp('2014-04-10 00:00:00'),
#   time                        2014-04-07  2014-04-08  2014-04-09
#         variable
#   value call                    1.000000    1.000000    1.000000
#         sms                          NaN    1.000000    1.000000
#         activity                0.183435    0.089063    0.117565
#         appCat.builtin         11.675891    9.750275    7.916894
#         appCat.communication   31.532337   26.370836   48.374627
#         appCat.other           12.716600    7.879000   12.125800
#         appCat.social          71.526667         NaN         NaN
#         circumplex.arousal     -1.000000   -0.400000   -0.400000
#         circumplex.valence      0.600000    1.000000    0.800000
#         mood                    6.600000    6.800000    7.200000
#         screen                 28.834902   30.887798   48.444159
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.utilities             NaN   13.335500         NaN,
#   6.75),
#  ('AS14.19',
#   Timestamp('2014-04-11 00:00:00'),
#   time                        2014-04-08  2014-04-09  2014-04-10
#         variable
#   value call                    1.000000    1.000000    1.000000
#         sms                     1.000000    1.000000         NaN
#         activity                0.089063    0.117565    0.072801
#         appCat.builtin          9.750275    7.916894   71.262356
#         appCat.communication   26.370836   48.374627   19.596091
#         appCat.other            7.879000   12.125800    8.070250
#         appCat.social                NaN         NaN   11.269000
#         circumplex.arousal     -0.400000   -0.400000   -0.500000
#         circumplex.valence      1.000000    0.800000    0.750000
#         mood                    6.800000    7.200000    6.750000
#         screen                 30.887798   48.444159   26.184875
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.utilities       13.335500         NaN         NaN,
#   6.8),
#  ('AS14.19',
#   Timestamp('2014-04-12 00:00:00'),
#   time                        2014-04-09  2014-04-10  2014-04-11
#         variable
#   value call                    1.000000    1.000000    1.000000
#         sms                     1.000000         NaN         NaN
#         activity                0.117565    0.072801    0.111094
#         appCat.builtin          7.916894   71.262356   15.904222
#         appCat.communication   48.374627   19.596091   25.619046
#         appCat.other           12.125800    8.070250    8.488400
#         appCat.social                NaN   11.269000   10.243667
#         circumplex.arousal     -0.400000   -0.500000   -0.600000
#         circumplex.valence      0.800000    0.750000    1.000000
#         mood                    7.200000    6.750000    6.800000
#         screen                 48.444159   26.184875   39.640029
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN,
#   7.2),
#  ('AS14.19',
#   Timestamp('2014-04-13 00:00:00'),
#   time                        2014-04-10  2014-04-11  2014-04-12
#         variable
#   value call                    1.000000    1.000000    1.000000
#         sms                          NaN         NaN         NaN
#         activity                0.072801    0.111094    0.066055
#         appCat.builtin         71.262356   15.904222   10.115778
#         appCat.communication   19.596091   25.619046   20.379583
#         appCat.other            8.070250    8.488400    9.092400
#         appCat.social          11.269000   10.243667   64.837500
#         circumplex.arousal     -0.500000   -0.600000    0.200000
#         circumplex.valence      0.750000    1.000000    0.800000
#         mood                    6.750000    6.800000    7.200000
#         screen                 26.184875   39.640029   31.786069
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN,
#   7.2),
#  ('AS14.19',
#   Timestamp('2014-04-14 00:00:00'),
#   time                        2014-04-11  2014-04-12  2014-04-13
#         variable
#   value call                    1.000000    1.000000    1.000000
#         sms                          NaN         NaN         NaN
#         activity                0.111094    0.066055    0.113674
#         appCat.builtin         15.904222   10.115778    5.710780
#         appCat.communication   25.619046   20.379583   22.551667
#         appCat.other            8.488400    9.092400   12.316800
#         appCat.social          10.243667   64.837500   15.125067
#         circumplex.arousal     -0.600000    0.200000   -0.600000
#         circumplex.valence      1.000000    0.800000    1.000000
#         mood                    6.800000    7.200000    7.200000
#         screen                 39.640029   31.786069   24.695197
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN,
#   7.0),
#  ('AS14.19',
#   Timestamp('2014-04-15 00:00:00'),
#   time                        2014-04-12  2014-04-13  2014-04-14
#         variable
#   value call                    1.000000    1.000000    1.000000
#         sms                          NaN         NaN         NaN
#         activity                0.066055    0.113674    0.145929
#         appCat.builtin         10.115778    5.710780   32.331315
#         appCat.communication   20.379583   22.551667   35.540189
#         appCat.other            9.092400   12.316800   13.727600
#         appCat.social          64.837500   15.125067  104.262500
#         circumplex.arousal      0.200000   -0.600000    0.400000
#         circumplex.valence      0.800000    1.000000    0.800000
#         mood                    7.200000    7.200000    7.000000
#         screen                 31.786069   24.695197   50.019650
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.unknown               NaN         NaN   10.570500
#         appCat.travel                NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN,
#   6.4),
#  ('AS14.19',
#   Timestamp('2014-04-16 00:00:00'),
#   time                        2014-04-13  2014-04-14  2014-04-15
#         variable
#   value call                    1.000000    1.000000    1.000000
#         sms                          NaN         NaN         NaN
#         activity                0.113674    0.145929    0.130766
#         appCat.builtin          5.710780   32.331315    9.674632
#         appCat.communication   22.551667   35.540189   37.815022
#         appCat.other           12.316800   13.727600   16.192286
#         appCat.social          15.125067  104.262500    9.601000
#         circumplex.arousal     -0.600000    0.400000   -1.000000
#         circumplex.valence      1.000000    0.800000    1.000000
#         mood                    7.200000    7.000000    6.400000
#         screen                 24.695197   50.019650   50.983869
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.unknown               NaN   10.570500    4.223667
#         appCat.travel                NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN,
#   6.8),
#  ('AS14.19',
#   Timestamp('2014-04-17 00:00:00'),
#   time                        2014-04-14  2014-04-15  2014-04-16
#         variable
#   value call                    1.000000    1.000000    1.000000
#         sms                          NaN         NaN    1.000000
#         activity                0.145929    0.130766    0.077214
#         appCat.builtin         32.331315    9.674632    6.817406
#         appCat.communication   35.540189   37.815022  103.842812
#         appCat.other           13.727600   16.192286   11.466400
#         appCat.social         104.262500    9.601000   39.414333
#         circumplex.arousal      0.400000   -1.000000   -0.600000
#         circumplex.valence      0.800000    1.000000    1.000000
#         mood                    7.000000    6.400000    6.800000
#         screen                 50.019650   50.983869   32.274310
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.unknown         10.570500    4.223667         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN,
#   6.8),
#  ('AS14.19',
#   Timestamp('2014-04-18 00:00:00'),
#   time                        2014-04-15  2014-04-16  2014-04-17
#         variable
#   value call                    1.000000    1.000000    1.000000
#         sms                          NaN    1.000000         NaN
#         activity                0.130766    0.077214    0.101468
#         appCat.builtin          9.674632    6.817406    5.991643
#         appCat.communication   37.815022  103.842812   51.215533
#         appCat.other           16.192286   11.466400    9.504000
#         appCat.social           9.601000   39.414333   48.973500
#         circumplex.arousal     -1.000000   -0.600000   -0.800000
#         circumplex.valence      1.000000    1.000000    1.000000
#         mood                    6.400000    6.800000    6.800000
#         screen                 50.983869   32.274310   62.710158
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.unknown          4.223667         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.game                  NaN         NaN         NaN
#         appCat.utilities             NaN         NaN         NaN,
#   6.8),
#  ('AS14.19',
#   Timestamp('2014-04-19 00:00:00'),
#   time                        2014-04-16  2014-04-17  2014-04-18
#         variable
#   value call                    1.000000    1.000000    1.000000
#         sms                     1.000000         NaN    1.000000
#         activity                0.077214    0.101468    0.064931
#         appCat.builtin          6.817406    5.991643    4.504667
#         appCat.communication  103.842812   51.215533   53.678381
#         appCat.other           11.466400    9.504000    7.224500
#         appCat.social          39.414333   48.973500         NaN
#         circumplex.arousal     -0.600000   -0.800000   -1.000000
#         circumplex.valence      1.000000    1.000000    1.000000
#         mood                    6.800000    6.800000    6.800000
#         screen                 32.274310   62.710158   71.923978
#         appCat.entertainment         NaN         NaN         NaN
#         appCat.unknown               NaN         NaN         NaN
#         appCat.travel                NaN         NaN         NaN
#         appCat.game                  NaN         NaN  229.132000
#         appCat.utilities             NaN         NaN         NaN,
#   6.8),
#  ...]
