# %%
import pandas as pd

filename='training_set_VU_DM.csv'

types = {'id': str, 'time': str, 'variable': str, 'value': float}

types = {'srch_id': int,
         'site_id': int,
         'click_bool': bool,
         'booking_bool': bool,
         'gross_booking_uds': float,
         'visitor_location_country_id': int,
         'visitor_hist_starrating': float,
         'visitor_hist_adr_usd': float,
         'prop_country_id': int,
         'prop_id': int,
         'prop_starrating': int,
         'prop_review_score': float,
         'prop_brand_bool': int,
         'prop_location_score1': float, 
         'prop_location_score2': float,
         'prop_log_historical_price': float, 
         'price_usd': float, 
         'promotion_flag': int,
         'srch_destination_id': int, 
         'srch_length_of_stay': int, 
         'srch_booking_window': int,
         'srch_adults_count': int, 
         'srch_children_count': int, 
         'srch_room_count': int,
         'srch_saturday_night_bool': bool, 
         'srch_query_affinity_score': float,
         'orig_destination_distance': float, 
         'random_bool': bool, 
         'comp1_rate' : 'Int64', 
         'comp1_inv': 'Int64',
         'comp1_rate_percent_diff': float, 
         'comp2_rate': 'Int64', 
         'comp2_inv': 'Int64',
         'comp2_rate_percent_diff': float, 
         'comp3_rate': 'Int64', 
         'comp3_inv': 'Int64',
         'comp3_rate_percent_diff': float, 
         'comp4_rate': 'Int64', 
         'comp4_inv': 'Int64',
         'comp4_rate_percent_diff': float, 
         'comp5_rate': 'Int64', 
         'comp5_inv': 'Int64',
         'comp5_rate_percent_diff': float,
         'comp6_rate': 'Int64',
         'comp6_inv': 'Int64',
         'comp6_rate_percent_diff': float,
         'comp7_rate': 'Int64',
         'comp7_inv': 'Int64',
         'comp7_rate_percent_diff': float,
         'comp8_rate': 'Int64',
         'comp8_inv': 'Int64',
         'comp8_rate_percent_diff': float}


parse_dates = ['date_time']
df_big = pd.read_csv(filename, dtype=types, index_col=['srch_id','prop_id'], parse_dates=parse_dates)

df_big.head()
# Out:
# C:\Users\murco\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                           date_time  site_id  visitor_location_country_id  \
# srch_id prop_id
# 1       893     2013-04-04 08:32:15       12                          187
#         10404   2013-04-04 08:32:15       12                          187
#         21315   2013-04-04 08:32:15       12                          187
#         27348   2013-04-04 08:32:15       12                          187
#         29604   2013-04-04 08:32:15       12                          187
#
#                  visitor_hist_starrating  visitor_hist_adr_usd  \
# srch_id prop_id
# 1       893                          NaN                   NaN
#         10404                        NaN                   NaN
#         21315                        NaN                   NaN
#         27348                        NaN                   NaN
#         29604                        NaN                   NaN
#
#                  prop_country_id  prop_starrating  prop_review_score  \
# srch_id prop_id
# 1       893                  219                3                3.5
#         10404                219                4                4.0
#         21315                219                3                4.5
#         27348                219                2                4.0
#         29604                219                4                3.5
#
#                  prop_brand_bool  prop_location_score1  ...  \
# srch_id prop_id                                         ...
# 1       893                    1                  2.83  ...
#         10404                  1                  2.20  ...
#         21315                  1                  2.20  ...
#         27348                  1                  2.83  ...
#         29604                  1                  2.64  ...
#
#                  comp6_rate_percent_diff  comp7_rate  comp7_inv  \
# srch_id prop_id
# 1       893                          NaN         NaN        NaN
#         10404                        NaN         NaN        NaN
#         21315                        NaN         NaN        NaN
#         27348                        NaN         NaN        NaN
#         29604                        NaN         NaN        NaN
#
#                  comp7_rate_percent_diff  comp8_rate  comp8_inv  \
# srch_id prop_id
# 1       893                          NaN           0          0
#         10404                        NaN           0          0
#         21315                        NaN           0          0
#         27348                        NaN          -1          0
#         29604                        NaN           0          0
#
#                  comp8_rate_percent_diff  click_bool  gross_bookings_usd  \
# srch_id prop_id
# 1       893                          NaN       False                 NaN
#         10404                        NaN       False                 NaN
#         21315                        NaN       False                 NaN
#         27348                        5.0       False                 NaN
#         29604                        NaN       False                 NaN
#
#                  booking_bool
# srch_id prop_id
# 1       893             False
#         10404           False
#         21315           False
#         27348           False
#         29604           False
#
# [5 rows x 52 columns]

# %%
# df_big.loc[~df_big['click_bool'] & df_big['booking_bool']]
df_big.groupby("srch_id").size().plot.density()

# %%
df_big.columns
# Out:
# Index(['date_time', 'site_id', 'visitor_location_country_id',
#        'visitor_hist_starrating', 'visitor_hist_adr_usd', 'prop_country_id',
#        'prop_starrating', 'prop_review_score', 'prop_brand_bool',
#        'prop_location_score1', 'prop_location_score2',
#        'prop_log_historical_price', 'position', 'price_usd', 'promotion_flag',
#        'srch_destination_id', 'srch_length_of_stay', 'srch_booking_window',
#        'srch_adults_count', 'srch_children_count', 'srch_room_count',
#        'srch_saturday_night_bool', 'srch_query_affinity_score',
#        'orig_destination_distance', 'random_bool', 'comp1_rate', 'comp1_inv',
#        'comp1_rate_percent_diff', 'comp2_rate', 'comp2_inv',
#        'comp2_rate_percent_diff', 'comp3_rate', 'comp3_inv',
#        'comp3_rate_percent_diff', 'comp4_rate', 'comp4_inv',
#        'comp4_rate_percent_diff', 'comp5_rate', 'comp5_inv',
#        'comp5_rate_percent_diff', 'comp6_rate', 'comp6_inv',
#        'comp6_rate_percent_diff', 'comp7_rate', 'comp7_inv',
#        'comp7_rate_percent_diff', 'comp8_rate', 'comp8_inv',
#        'comp8_rate_percent_diff', 'click_bool', 'gross_bookings_usd',
#        'booking_bool'],
#       dtype='object')

# %%
df_chunk = df_big[:50000]

# %%
# pd.pivot_table(df_chunk, index=['srch_id']).head()

# %%
df_chunk

# %%
import pandas as pd

filename='tiny_train.csv'

types = {'id': str, 'time': str, 'variable': str, 'value': float}

types = {'srch_id': int,
         'site_id': int,
         'click_bool': bool,
         'booking_bool': bool,
         'gross_booking_uds': float,
         'visitor_location_country_id': int,
         'visitor_hist_starrating': float,
         'visitor_hist_adr_usd': float,
         'prop_country_id': int,
         'prop_id': int,
         'prop_starrating': int,
         'prop_review_score': float,
         'prop_brand_bool': int,
         'prop_location_score1': float, 
         'prop_location_score2': float,
         'prop_log_historical_price': float, 
         'price_usd': float, 
         'promotion_flag': int,
         'srch_destination_id': int, 
         'srch_length_of_stay': int, 
         'srch_booking_window': int,
         'srch_adults_count': int, 
         'srch_children_count': int, 
         'srch_room_count': int,
         'srch_saturday_night_bool': bool, 
         'srch_query_affinity_score': float,
         'orig_destination_distance': float, 
         'random_bool': bool, 
         'comp1_rate' : 'Int64', 
         'comp1_inv': 'Int64',
         'comp1_rate_percent_diff': float, 
         'comp2_rate': 'Int64', 
         'comp2_inv': 'Int64',
         'comp2_rate_percent_diff': float, 
         'comp3_rate': 'Int64', 
         'comp3_inv': 'Int64',
         'comp3_rate_percent_diff': float, 
         'comp4_rate': 'Int64', 
         'comp4_inv': 'Int64',
         'comp4_rate_percent_diff': float, 
         'comp5_rate': 'Int64', 
         'comp5_inv': 'Int64',
         'comp5_rate_percent_diff': float,
         'comp6_rate': 'Int64',
         'comp6_inv': 'Int64',
         'comp6_rate_percent_diff': float,
         'comp7_rate': 'Int64',
         'comp7_inv': 'Int64',
         'comp7_rate_percent_diff': float,
         'comp8_rate': 'Int64',
         'comp8_inv': 'Int64',
         'comp8_rate_percent_diff': float}


parse_dates = ['date_time']
df = pd.read_csv(filename, dtype=types, index_col=['srch_id', 'position', 'prop_id', 'click_bool',
'booking_bool'], parse_dates=parse_dates)

df.sort_index(level=['srch_id', 'booking_bool'], inplace=True)

df.head()
# Out:
#                                                            date_time  site_id  \
# srch_id position prop_id click_bool booking_bool
# 405     2        8289    False      False        2013-02-05 03:19:22        5
#         3        93384   False      False        2013-02-05 03:19:22        5
#         4        88553   False      False        2013-02-05 03:19:22        5
#         6        121975  False      False        2013-02-05 03:19:22        5
#         7        14041   False      False        2013-02-05 03:19:22        5
#
#                                                   visitor_location_country_id  \
# srch_id position prop_id click_bool booking_bool
# 405     2        8289    False      False                                  98
#         3        93384   False      False                                  98
#         4        88553   False      False                                  98
#         6        121975  False      False                                  98
#         7        14041   False      False                                  98
#
#                                                   visitor_hist_starrating  \
# srch_id position prop_id click_bool booking_bool
# 405     2        8289    False      False                             NaN
#         3        93384   False      False                             NaN
#         4        88553   False      False                             NaN
#         6        121975  False      False                             NaN
#         7        14041   False      False                             NaN
#
#                                                   visitor_hist_adr_usd  \
# srch_id position prop_id click_bool booking_bool
# 405     2        8289    False      False                          NaN
#         3        93384   False      False                          NaN
#         4        88553   False      False                          NaN
#         6        121975  False      False                          NaN
#         7        14041   False      False                          NaN
#
#                                                   prop_country_id  \
# srch_id position prop_id click_bool booking_bool
# 405     2        8289    False      False                     219
#         3        93384   False      False                     219
#         4        88553   False      False                     219
#         6        121975  False      False                     219
#         7        14041   False      False                     219
#
#                                                   prop_starrating  \
# srch_id position prop_id click_bool booking_bool
# 405     2        8289    False      False                       4
#         3        93384   False      False                       4
#         4        88553   False      False                       3
#         6        121975  False      False                       3
#         7        14041   False      False                       4
#
#                                                   prop_review_score  \
# srch_id position prop_id click_bool booking_bool
# 405     2        8289    False      False                       4.5
#         3        93384   False      False                       4.5
#         4        88553   False      False                       4.5
#         6        121975  False      False                       4.5
#         7        14041   False      False                       4.5
#
#                                                   prop_brand_bool  \
# srch_id position prop_id click_bool booking_bool
# 405     2        8289    False      False                       1
#         3        93384   False      False                       1
#         4        88553   False      False                       1
#         6        121975  False      False                       1
#         7        14041   False      False                       1
#
#                                                   prop_location_score1  ...  \
# srch_id position prop_id click_bool booking_bool                        ...
# 405     2        8289    False      False                         4.41  ...
#         3        93384   False      False                         4.76  ...
#         4        88553   False      False                         4.54  ...
#         6        121975  False      False                         4.70  ...
#         7        14041   False      False                         0.00  ...
#
#                                                   comp6_rate  comp6_inv  \
# srch_id position prop_id click_bool booking_bool
# 405     2        8289    False      False                NaN        NaN
#         3        93384   False      False                NaN        NaN
#         4        88553   False      False                NaN        NaN
#         6        121975  False      False                NaN        NaN
#         7        14041   False      False                NaN        NaN
#
#                                                   comp6_rate_percent_diff  \
# srch_id position prop_id click_bool booking_bool
# 405     2        8289    False      False                             NaN
#         3        93384   False      False                             NaN
#         4        88553   False      False                             NaN
#         6        121975  False      False                             NaN
#         7        14041   False      False                             NaN
#
#                                                   comp7_rate  comp7_inv  \
# srch_id position prop_id click_bool booking_bool
# 405     2        8289    False      False                NaN        NaN
#         3        93384   False      False                NaN        NaN
#         4        88553   False      False                NaN        NaN
#         6        121975  False      False                NaN        NaN
#         7        14041   False      False                NaN        NaN
#
#                                                   comp7_rate_percent_diff  \
# srch_id position prop_id click_bool booking_bool
# 405     2        8289    False      False                             NaN
#         3        93384   False      False                             NaN
#         4        88553   False      False                             NaN
#         6        121975  False      False                             NaN
#         7        14041   False      False                             NaN
#
#                                                   comp8_rate  comp8_inv  \
# srch_id position prop_id click_bool booking_bool
# 405     2        8289    False      False                  0          0
#         3        93384   False      False                  0          0
#         4        88553   False      False                  0          0
#         6        121975  False      False                  0          0
#         7        14041   False      False                  0          0
#
#                                                   comp8_rate_percent_diff  \
# srch_id position prop_id click_bool booking_bool
# 405     2        8289    False      False                             5.0
#         3        93384   False      False                             NaN
#         4        88553   False      False                             NaN
#         6        121975  False      False                             NaN
#         7        14041   False      False                             5.0
#
#                                                   gross_bookings_usd
# srch_id position prop_id click_bool booking_bool
# 405     2        8289    False      False                        NaN
#         3        93384   False      False                        NaN
#         4        88553   False      False                        NaN
#         6        121975  False      False                        NaN
#         7        14041   False      False                        NaN
#
# [5 rows x 49 columns]

# %%
# df

# %%
df.columns
# Out:
# Index(['date_time', 'site_id', 'visitor_location_country_id',
#        'visitor_hist_starrating', 'visitor_hist_adr_usd', 'prop_country_id',
#        'prop_starrating', 'prop_review_score', 'prop_brand_bool',
#        'prop_location_score1', 'prop_location_score2',
#        'prop_log_historical_price', 'price_usd', 'promotion_flag',
#        'srch_destination_id', 'srch_length_of_stay', 'srch_booking_window',
#        'srch_adults_count', 'srch_children_count', 'srch_room_count',
#        'srch_saturday_night_bool', 'srch_query_affinity_score',
#        'orig_destination_distance', 'random_bool', 'comp1_rate', 'comp1_inv',
#        'comp1_rate_percent_diff', 'comp2_rate', 'comp2_inv',
#        'comp2_rate_percent_diff', 'comp3_rate', 'comp3_inv',
#        'comp3_rate_percent_diff', 'comp4_rate', 'comp4_inv',
#        'comp4_rate_percent_diff', 'comp5_rate', 'comp5_inv',
#        'comp5_rate_percent_diff', 'comp6_rate', 'comp6_inv',
#        'comp6_rate_percent_diff', 'comp7_rate', 'comp7_inv',
#        'comp7_rate_percent_diff', 'comp8_rate', 'comp8_inv',
#        'comp8_rate_percent_diff', 'gross_bookings_usd'],
#       dtype='object')

# %%
df.reset_index(inplace=True)

# %%
from datetime import datetime  
from datetime import timedelta 


df['srch_booking_window'] = df['srch_booking_window'].apply(lambda x: timedelta(days = x))

df['time_of_booking'] = df['date_time'] + df['srch_booking_window']

# %%
import numpy as np

df['SPRING'] = np.where(pd.DatetimeIndex(df.time_of_booking).month.isin([3,4,5]), 1, 0)
df['SUMMER'] = np.where(pd.DatetimeIndex(df.time_of_booking).month.isin([6,7,8]), 1, 0)
df['AUTUMN'] = np.where(pd.DatetimeIndex(df.time_of_booking).month.isin([9,10,11]), 1, 0)
df['WINTER'] = np.where(pd.DatetimeIndex(df.time_of_booking).month.isin([12,1,2]), 1, 0)

# %%
import matplotlib.pyplot as plt


df.isna().sum().sort_values().plot(kind='bar', figsize=(10,10), logy=True)
plt.show()

# %%
len(df['prop_id'].unique())
# Out:
# 17526

# %%
from pandas.plotting import scatter_matrix

to_do = [
    'visitor_hist_starrating',
    'visitor_hist_adr_usd',
    'prop_starrating',
    'prop_review_score',
    'prop_location_score1',
    'prop_location_score2',
    'prop_log_historical_price',
    'price_usd',
    'srch_destination_id',
    'srch_length_of_stay',
    'srch_booking_window',
    'srch_adults_count',
    'srch_children_count',
    'srch_room_count',
    'srch_query_affinity_score',
    'orig_destination_distance',]

if False:

    axes = scatter_matrix(df[to_do], alpha=0.2, figsize=(6, 6), diagonal='kde')

    for list in axes:
        for axe in list:
            plt.setp(axe.get_xticklabels(), visible=False)
            plt.setp(axe.get_yticklabels(), visible=False)
            axe.set_xlabel(axe.get_xlabel().split(".")[-1], rotation=45, rotation_mode='anchor', ha="right")
            axe.set_ylabel(axe.get_ylabel().split(".")[-1], rotation=0, rotation_mode='anchor', ha="right")

    plt.show()

# %%
plt.matshow(df.corr())
plt.show()

# %%
# df.corr()

# %%
df.head()
# Out:
#    srch_id  position  prop_id  click_bool  booking_bool           date_time  \
# 0      405         2     8289       False         False 2013-02-05 03:19:22
# 1      405         3    93384       False         False 2013-02-05 03:19:22
# 2      405         4    88553       False         False 2013-02-05 03:19:22
# 3      405         6   121975       False         False 2013-02-05 03:19:22
# 4      405         7    14041       False         False 2013-02-05 03:19:22
#
#    site_id  visitor_location_country_id  visitor_hist_starrating  \
# 0        5                           98                      NaN
# 1        5                           98                      NaN
# 2        5                           98                      NaN
# 3        5                           98                      NaN
# 4        5                           98                      NaN
#
#    visitor_hist_adr_usd  ...  comp7_rate_percent_diff  comp8_rate  comp8_inv  \
# 0                   NaN  ...                      NaN           0          0
# 1                   NaN  ...                      NaN           0          0
# 2                   NaN  ...                      NaN           0          0
# 3                   NaN  ...                      NaN           0          0
# 4                   NaN  ...                      NaN           0          0
#
#    comp8_rate_percent_diff  gross_bookings_usd     time_of_booking  SPRING  \
# 0                      5.0                 NaN 2013-03-17 03:19:22       1
# 1                      NaN                 NaN 2013-03-17 03:19:22       1
# 2                      NaN                 NaN 2013-03-17 03:19:22       1
# 3                      NaN                 NaN 2013-03-17 03:19:22       1
# 4                      5.0                 NaN 2013-03-17 03:19:22       1
#
#    SUMMER  AUTUMN  WINTER
# 0       0       0       0
# 1       0       0       0
# 2       0       0       0
# 3       0       0       0
# 4       0       0       0
#
# [5 rows x 59 columns]

# %%
all_comp_rates = ['comp' + str(x) + '_rate' for x in range(1,9)]
all_comp_invs = ['comp' + str(x) + '_inv' for x in range(1,9)]
all_comp_diff = ['comp' + str(x) + '_rate_percent_diff' for x in range(1,9)]

df['comp_rate_avg'] = df[all_comp_rates].mean(axis=1) 
df['comp_inv_avg'] = df[all_comp_invs].mean(axis=1) 
df['comp_diff_avg'] = df[all_comp_diff].mean(axis=1) 

df = df.drop(all_comp_rates + all_comp_invs + all_comp_diff, axis=1)

# %%
for col in df.columns:
    print(col)
# Out:
# srch_id
# position
# prop_id
# click_bool
# booking_bool
# date_time
# site_id
# visitor_location_country_id
# visitor_hist_starrating
# visitor_hist_adr_usd
# prop_country_id
# prop_starrating
# prop_review_score
# prop_brand_bool
# prop_location_score1
# prop_location_score2
# prop_log_historical_price
# price_usd
# promotion_flag
# srch_destination_id
# srch_length_of_stay
# srch_booking_window
# srch_adults_count
# srch_children_count
# srch_room_count
# srch_saturday_night_bool
# srch_query_affinity_score
# orig_destination_distance
# random_bool
# gross_bookings_usd
# time_of_booking
# SPRING
# SUMMER
# AUTUMN
# WINTER
# comp_rate_avg
# comp_inv_avg
# comp_diff_avg

# %%
df = df.reset_index()
df.loc[df['click_bool'] & df['booking_bool']]
# Out:
#        index  srch_id  position  prop_id  click_bool  booking_bool  \
# 32        32      405         1   101503        True          True
# 64        64      507         1    46961        True          True
# 98        98      724         6    19938        True          True
# 136      136     1600         4    14646        True          True
# 176      176     1763        18   131863        True          True
# 240      240     1826         1    50450        True          True
# 260      260     2344         1    18584        True          True
# 356      356     3331         4   119123        True          True
# 388      388     3596         6    76443        True          True
# 422      422     3633        31    70273        True          True
# 452      452     4473         1   133720        True          True
# 551      551     5662        28   130373        True          True
# 594      594     6584         9    43883        True          True
# 621      621     6634        21      601        True          True
# 676      676     7022         3   126657        True          True
# 709      709     7048         4    79931        True          True
# 814      814     7786        19    46951        True          True
# 824      824     7859         1    50417        True          True
# 883      883     8150         3    34054        True          True
# 978      978     8370        32   112891        True          True
# 1004    1004     8450        12    12214        True          True
# 1066    1066     9759         9    54999        True          True
# 1143    1143    10482        15    97244        True          True
# 1172    1172    11933        29    77475        True          True
# 1203    1203    11989        10    93311        True          True
# 1229    1229    12125         1    76932        True          True
# 1259    1259    12467        14   100304        True          True
# 1302    1302    13635         9    84911        True          True
# 1334    1334    13893        26      832        True          True
# 1365    1365    14772        13   122895        True          True
# ...      ...      ...       ...      ...         ...           ...
# 23727  23727   321034        10   134879        True          True
# 23768  23768   321407         7   135146        True          True
# 23800  23800   321976         4   126732        True          True
# 23832  23832   322196         6   131917        True          True
# 23863  23863   322247         1    34428        True          True
# 23909  23909   322834         7   138229        True          True
# 23943  23943   322840         2    12005        True          True
# 23949  23949   323003         1   125522        True          True
# 24017  24017   323442         6   120562        True          True
# 24033  24033   324093         7    24865        True          True
# 24066  24066   324262         4    85294        True          True
# 24100  24100   324307         6    77435        True          True
# 24119  24119   324564         4    41492        True          True
# 24166  24166   324832        28    88218        True          True
# 24210  24210   325039        13    78495        True          True
# 24241  24241   325861         3   105408        True          True
# 24308  24308   326472         2    59587        True          True
# 24339  24339   326549         1    81549        True          True
# 24377  24377   329014         1      854        True          True
# 24426  24426   329567         4    53341        True          True
# 24492  24492   330183         1   104087        True          True
# 24519  24519   330589        22     5090        True          True
# 24527  24527   330754         1    83717        True          True
# 24622  24622   331097         1    17270        True          True
# 24644  24644   331428        12    44323        True          True
# 24677  24677   331478        14   134057        True          True
# 24705  24705   331514        10    21322        True          True
# 24736  24736   331650         2    96996        True          True
# 24762  24762   332101         1    71254        True          True
# 24794  24794   332289        30    90845        True          True
#
#                 date_time  site_id  visitor_location_country_id  \
# 32    2013-02-05 03:19:22        5                           98
# 64    2013-03-31 15:52:29        5                           32
# 98    2013-03-20 11:40:34        5                          219
# 136   2013-04-09 11:40:04        5                          219
# 176   2013-02-12 23:37:00       14                          100
# 240   2013-06-20 12:18:44        5                          219
# 260   2013-02-04 22:26:31       23                          181
# 356   2013-06-02 06:43:48        5                          219
# 388   2013-03-15 15:12:00        5                          219
# 422   2013-03-24 05:31:32        5                          219
# 452   2013-06-09 16:32:17       14                          100
# 551   2012-11-07 09:52:47        5                          219
# 594   2012-11-08 17:11:36        5                          117
# 621   2013-02-24 09:59:31       24                          216
# 676   2013-02-23 16:56:00       32                          220
# 709   2013-02-25 18:54:45        5                          219
# 814   2013-03-20 20:16:44       22                           92
# 824   2013-06-17 12:13:34       15                           55
# 883   2013-01-07 21:13:11        5                          219
# 978   2013-02-15 19:39:11       15                           55
# 1004  2012-11-12 16:22:59        5                          219
# 1066  2013-02-22 18:36:55       18                          221
# 1143  2013-06-21 19:13:45       22                           92
# 1172  2013-03-06 17:53:47        5                          219
# 1203  2013-02-17 20:38:45        5                          219
# 1229  2012-12-01 09:20:47        5                          219
# 1259  2013-03-21 08:53:13       14                           92
# 1302  2013-03-19 13:11:42       15                           55
# 1334  2013-01-29 04:55:49        5                          219
# 1365  2013-02-20 10:17:28       32                          220
# ...                   ...      ...                          ...
# 23727 2013-06-14 08:16:15       14                          100
# 23768 2013-04-24 17:04:15       24                          216
# 23800 2012-12-25 19:38:15        5                           59
# 23832 2013-01-21 06:17:38       14                          100
# 23863 2013-05-29 17:28:08        5                          219
# 23909 2013-05-27 08:40:39        5                          219
# 23943 2013-02-19 21:42:25        5                          219
# 23949 2013-01-16 07:06:30        5                          214
# 24017 2013-05-03 00:45:57       14                          100
# 24033 2013-06-11 08:44:32       14                          100
# 24066 2013-05-17 13:07:57        5                          219
# 24100 2012-11-05 10:44:28        5                          219
# 24119 2013-04-20 17:57:24       24                          216
# 24166 2013-03-28 18:52:53        5                          219
# 24210 2013-01-10 16:59:54       15                           55
# 24241 2013-06-16 10:17:40        5                          219
# 24308 2013-05-31 14:19:37        5                          219
# 24339 2013-01-06 19:42:48        5                          219
# 24377 2013-04-08 10:53:38       14                          100
# 24426 2013-06-04 15:00:53        5                          219
# 24492 2012-11-07 06:47:10       18                          219
# 24519 2013-06-06 19:05:15       22                           92
# 24527 2013-04-15 08:56:14        5                          138
# 24622 2013-02-07 00:02:15       15                          219
# 24644 2013-03-10 16:10:27        5                           22
# 24677 2013-04-26 16:09:00        5                          219
# 24705 2013-06-07 16:38:15       18                          129
# 24736 2012-11-17 12:22:44        5                          219
# 24762 2013-04-03 16:51:21        5                          219
# 24794 2013-05-05 22:01:43        5                          219
#
#        visitor_hist_starrating  ...  random_bool  gross_bookings_usd  \
# 32                         NaN  ...        False             2425.32
# 64                         NaN  ...        False              534.61
# 98                         NaN  ...        False               98.80
# 136                        NaN  ...        False              307.76
# 176                        NaN  ...        False             1095.98
# 240                        NaN  ...        False              386.40
# 260                        NaN  ...        False             1664.66
# 356                        NaN  ...        False              103.07
# 388                        NaN  ...        False              151.41
# 422                        NaN  ...        False              111.02
# 452                        NaN  ...        False              610.84
# 551                        NaN  ...        False              205.18
# 594                        NaN  ...        False              717.31
# 621                        NaN  ...        False              121.56
# 676                       4.10  ...        False             2266.53
# 709                        NaN  ...        False              150.34
# 814                        NaN  ...        False              144.97
# 824                        NaN  ...         True              438.20
# 883                        NaN  ...        False               97.65
# 978                        NaN  ...         True              201.43
# 1004                       NaN  ...        False              335.40
# 1066                       NaN  ...        False              292.80
# 1143                       NaN  ...        False              451.59
# 1172                       NaN  ...        False              752.01
# 1203                       NaN  ...        False              430.58
# 1229                       NaN  ...        False               62.67
# 1259                       NaN  ...        False              506.28
# 1302                       NaN  ...        False              356.50
# 1334                       NaN  ...        False              103.94
# 1365                       NaN  ...        False              283.07
# ...                        ...  ...          ...                 ...
# 23727                      NaN  ...        False              231.92
# 23768                      NaN  ...        False              627.40
# 23800                      NaN  ...        False             2607.78
# 23832                      NaN  ...        False              155.92
# 23863                      NaN  ...        False              275.00
# 23909                      NaN  ...        False              416.10
# 23943                      NaN  ...        False              346.82
# 23949                      NaN  ...        False              441.06
# 24017                     3.80  ...        False              832.34
# 24033                      NaN  ...        False              191.10
# 24066                      NaN  ...        False              123.10
# 24100                      NaN  ...        False              156.68
# 24119                      NaN  ...        False               65.26
# 24166                      NaN  ...        False              155.19
# 24210                      NaN  ...        False              158.63
# 24241                      NaN  ...        False              197.43
# 24308                      NaN  ...        False              367.42
# 24339                      NaN  ...        False              411.45
# 24377                      NaN  ...        False              199.03
# 24426                      NaN  ...        False              253.68
# 24492                      NaN  ...        False              394.47
# 24519                      NaN  ...        False              663.08
# 24527                      NaN  ...        False              322.32
# 24622                      NaN  ...         True              121.77
# 24644                      NaN  ...        False              943.20
# 24677                      NaN  ...        False              308.16
# 24705                      NaN  ...         True             1092.31
# 24736                     3.97  ...        False              507.53
# 24762                      NaN  ...        False              208.80
# 24794                      NaN  ...        False              238.42
#
#           time_of_booking  SPRING  SUMMER  AUTUMN  WINTER  comp_rate_avg  \
# 32    2013-03-17 03:19:22       1       0       0       0       0.000000
# 64    2013-04-19 15:52:29       1       0       0       0       0.333333
# 98    2013-03-22 11:40:34       1       0       0       0       0.000000
# 136   2013-09-11 11:40:04       0       0       1       0            NaN
# 176   2013-03-07 23:37:00       1       0       0       0            NaN
# 240   2013-06-25 12:18:44       0       1       0       0       0.000000
# 260   2013-02-23 22:26:31       0       0       0       1      -1.000000
# 356   2013-06-02 06:43:48       0       1       0       0            NaN
# 388   2013-03-20 15:12:00       1       0       0       0       0.000000
# 422   2013-03-24 05:31:32       1       0       0       0       0.000000
# 452   2013-08-02 16:32:17       0       1       0       0            NaN
# 551   2012-12-06 09:52:47       0       0       0       1       0.000000
# 594   2012-11-28 17:11:36       0       0       1       0            NaN
# 621   2013-08-17 09:59:31       0       1       0       0            NaN
# 676   2013-04-05 16:56:00       1       0       0       0       0.000000
# 709   2013-02-28 18:54:45       0       0       0       1       0.000000
# 814   2013-03-29 20:16:44       1       0       0       0      -0.500000
# 824   2013-06-18 12:13:34       0       1       0       0            NaN
# 883   2013-01-11 21:13:11       0       0       0       1            NaN
# 978   2013-03-26 19:39:11       1       0       0       0            NaN
# 1004  2012-12-27 16:22:59       0       0       0       1       0.000000
# 1066  2013-02-22 18:36:55       0       0       0       1       0.000000
# 1143  2013-07-24 19:13:45       0       1       0       0       0.000000
# 1172  2013-03-27 17:53:47       1       0       0       0            NaN
# 1203  2013-05-11 20:38:45       1       0       0       0       0.000000
# 1229  2012-12-01 09:20:47       0       0       0       1      -1.000000
# 1259  2013-03-27 08:53:13       1       0       0       0       0.000000
# 1302  2013-08-03 13:11:42       0       1       0       0            NaN
# 1334  2013-01-29 04:55:49       0       0       0       1            NaN
# 1365  2013-02-25 10:17:28       0       0       0       1       0.000000
# ...                   ...     ...     ...     ...     ...            ...
# 23727 2013-06-21 08:16:15       0       1       0       0       0.250000
# 23768 2013-05-16 17:04:15       1       0       0       0       0.000000
# 23800 2013-07-23 19:38:15       0       1       0       0            NaN
# 23832 2013-01-30 06:17:38       0       0       0       1       0.000000
# 23863 2013-07-05 17:28:08       0       1       0       0      -1.000000
# 23909 2013-07-19 08:40:39       0       1       0       0       0.000000
# 23943 2013-02-22 21:42:25       0       0       0       1       0.000000
# 23949 2013-01-20 07:06:30       0       0       0       1       0.000000
# 24017 2013-08-02 00:45:57       0       1       0       0            NaN
# 24033 2013-06-15 08:44:32       0       1       0       0       0.000000
# 24066 2013-05-24 13:07:57       1       0       0       0       0.000000
# 24100 2012-11-09 10:44:28       0       0       1       0      -1.000000
# 24119 2013-05-02 17:57:24       1       0       0       0       0.000000
# 24166 2013-04-04 18:52:53       1       0       0       0       0.000000
# 24210 2013-01-17 16:59:54       0       0       0       1            NaN
# 24241 2013-06-17 10:17:40       0       1       0       0       0.000000
# 24308 2013-06-21 14:19:37       0       1       0       0            NaN
# 24339 2013-01-11 19:42:48       0       0       0       1       0.250000
# 24377 2013-04-09 10:53:38       1       0       0       0      -0.333333
# 24426 2013-06-06 15:00:53       0       1       0       0       0.000000
# 24492 2012-11-08 06:47:10       0       0       1       0       0.000000
# 24519 2013-08-16 19:05:15       0       1       0       0       0.500000
# 24527 2013-05-01 08:56:14       1       0       0       0       0.000000
# 24622 2013-02-17 00:02:15       0       0       0       1       0.000000
# 24644 2013-05-14 16:10:27       1       0       0       0            NaN
# 24677 2013-05-02 16:09:00       1       0       0       0       0.000000
# 24705 2013-07-05 16:38:15       0       1       0       0      -1.000000
# 24736 2012-12-16 12:22:44       0       0       0       1      -1.000000
# 24762 2013-06-14 16:51:21       0       1       0       0            NaN
# 24794 2013-06-14 22:01:43       0       1       0       0       0.000000
#
#        comp_inv_avg  comp_diff_avg
# 32         0.000000            NaN
# 64         0.000000       7.333333
# 98         0.250000            NaN
# 136             NaN            NaN
# 176             NaN            NaN
# 240        0.000000            NaN
# 260        0.000000      22.000000
# 356             NaN            NaN
# 388        0.000000       9.333333
# 422        0.000000            NaN
# 452             NaN            NaN
# 551        0.000000            NaN
# 594             NaN            NaN
# 621             NaN            NaN
# 676        0.000000      10.000000
# 709        0.000000            NaN
# 814        0.000000       9.000000
# 824       -1.000000            NaN
# 883             NaN            NaN
# 978             NaN            NaN
# 1004       0.000000            NaN
# 1066       0.000000            NaN
# 1143       0.000000            NaN
# 1172            NaN            NaN
# 1203       0.000000            NaN
# 1229       0.000000      12.000000
# 1259       0.000000            NaN
# 1302            NaN            NaN
# 1334      -1.000000            NaN
# 1365       0.000000            NaN
# ...             ...            ...
# 23727      0.000000      15.000000
# 23768      0.000000            NaN
# 23800           NaN            NaN
# 23832      0.000000            NaN
# 23863      0.000000       7.000000
# 23909      0.000000            NaN
# 23943      0.000000            NaN
# 23949      0.000000            NaN
# 24017           NaN            NaN
# 24033      0.333333            NaN
# 24066      0.000000            NaN
# 24100      0.000000       8.000000
# 24119      0.000000            NaN
# 24166      0.000000      19.000000
# 24210           NaN            NaN
# 24241      0.000000       9.333333
# 24308           NaN            NaN
# 24339      0.000000      16.000000
# 24377      0.333333       8.666667
# 24426      0.000000      20.000000
# 24492      0.000000       3.000000
# 24519      0.000000      20.000000
# 24527      0.000000     101.250000
# 24622      0.000000      48.000000
# 24644           NaN            NaN
# 24677      0.000000      15.000000
# 24705      0.000000      17.000000
# 24736      0.000000      39.000000
# 24762           NaN            NaN
# 24794      0.000000            NaN
#
# [693 rows x 39 columns]

# %%
import matplotlib.pyplot as plt

df.isna().sum().sort_values().plot(kind='bar', figsize=(6,6), logy=True)
plt.show()
# Out:
# C:\Users\murco\Anaconda3\lib\site-packages\matplotlib\ticker.py:2198: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   "Data has no positive values, and therefore cannot be "

# %%
# df['visitor_hist_starrating'].plot.density()
# df['visitor_hist_adr_usd'].plot.density()
# df['prop_review_score'].plot.density()
# df['prop_location_score2'].plot.density()
# df['srch_query_affinity_score'].plot.density()
# df['orig_destination_distance'].plot.density()
# df['gross_bookings_usd'].plot.density()

# df['comp_rate_avg'].plot.density()
# df['comp_inv_avg'].plot.density()
# df['comp_diff_avg'].plot.density()

# df['prop_log_historical_price'].plot.density()
df['price_usd'].plot.density()

# %%
df['visitor_hist_starrating'].min()
df['prop_review_score'].min()
df['prop_location_score2'].min()

# df['srch_query_affinity_score'].max()

df['orig_destination_distance'].min()
df['gross_bookings_usd'].min()
# Out:
# 0.7

# %%
df.groupby("srch_id").size().plot.density()

# %%
values = {  'visitor_hist_starrating': -1,
            'visitor_hist_adr_usd': -1,
            'prop_review_score': -1,
            'prop_location_score2': -1,
            'srch_query_affinity_score': 0,
            'orig_destination_distance': -1,
            'gross_bookings_usd': -1,
            'comp_rate_avg': 0,
            'comp_inv_avg': 0,
            'comp_diff_avg': 0,}
df.fillna(value=values,inplace=True)

df.isna().sum()
# Out:
# index                          0
# srch_id                        0
# position                       0
# prop_id                        0
# click_bool                     0
# booking_bool                   0
# date_time                      0
# site_id                        0
# visitor_location_country_id    0
# visitor_hist_starrating        0
# visitor_hist_adr_usd           0
# prop_country_id                0
# prop_starrating                0
# prop_review_score              0
# prop_brand_bool                0
# prop_location_score1           0
# prop_location_score2           0
# prop_log_historical_price      0
# price_usd                      0
# promotion_flag                 0
# srch_destination_id            0
# srch_length_of_stay            0
# srch_booking_window            0
# srch_adults_count              0
# srch_children_count            0
# srch_room_count                0
# srch_saturday_night_bool       0
# srch_query_affinity_score      0
# orig_destination_distance      0
# random_bool                    0
# gross_bookings_usd             0
# time_of_booking                0
# SPRING                         0
# SUMMER                         0
# AUTUMN                         0
# WINTER                         0
# comp_rate_avg                  0
# comp_inv_avg                   0
# comp_diff_avg                  0
# dtype: int64

# %%
df.groupby("prop_country_id").price_usd.describe()[['mean','std']].plot(kind='scatter', x='mean', y='std')


# .price_usd.plot.kde()
# df.groupby("prop_country_id").price_usd.mean().plot(kind='scatter')

# %%
df.groupby("prop_country_id").price_usd.plot.kde(xlim=(0,500))
# Out:
# prop_country_id
# 4      AxesSubplot(0.125,0.125;0.775x0.755)
# 9      AxesSubplot(0.125,0.125;0.775x0.755)
# 13     AxesSubplot(0.125,0.125;0.775x0.755)
# 15     AxesSubplot(0.125,0.125;0.775x0.755)
# 16     AxesSubplot(0.125,0.125;0.775x0.755)
# 18     AxesSubplot(0.125,0.125;0.775x0.755)
# 22     AxesSubplot(0.125,0.125;0.775x0.755)
# 23     AxesSubplot(0.125,0.125;0.775x0.755)
# 26     AxesSubplot(0.125,0.125;0.775x0.755)
# 27     AxesSubplot(0.125,0.125;0.775x0.755)
# 31     AxesSubplot(0.125,0.125;0.775x0.755)
# 32     AxesSubplot(0.125,0.125;0.775x0.755)
# 34     AxesSubplot(0.125,0.125;0.775x0.755)
# 35     AxesSubplot(0.125,0.125;0.775x0.755)
# 37     AxesSubplot(0.125,0.125;0.775x0.755)
# 39     AxesSubplot(0.125,0.125;0.775x0.755)
# 41     AxesSubplot(0.125,0.125;0.775x0.755)
# 48     AxesSubplot(0.125,0.125;0.775x0.755)
# 50     AxesSubplot(0.125,0.125;0.775x0.755)
# 53     AxesSubplot(0.125,0.125;0.775x0.755)
# 55     AxesSubplot(0.125,0.125;0.775x0.755)
# 56     AxesSubplot(0.125,0.125;0.775x0.755)
# 59     AxesSubplot(0.125,0.125;0.775x0.755)
# 60     AxesSubplot(0.125,0.125;0.775x0.755)
# 68     AxesSubplot(0.125,0.125;0.775x0.755)
# 70     AxesSubplot(0.125,0.125;0.775x0.755)
# 72     AxesSubplot(0.125,0.125;0.775x0.755)
# 73     AxesSubplot(0.125,0.125;0.775x0.755)
# 77     AxesSubplot(0.125,0.125;0.775x0.755)
# 80     AxesSubplot(0.125,0.125;0.775x0.755)
#                        ...
# 109    AxesSubplot(0.125,0.125;0.775x0.755)
# 112    AxesSubplot(0.125,0.125;0.775x0.755)
# 117    AxesSubplot(0.125,0.125;0.775x0.755)
# 119    AxesSubplot(0.125,0.125;0.775x0.755)
# 124    AxesSubplot(0.125,0.125;0.775x0.755)
# 129    AxesSubplot(0.125,0.125;0.775x0.755)
# 132    AxesSubplot(0.125,0.125;0.775x0.755)
# 134    AxesSubplot(0.125,0.125;0.775x0.755)
# 138    AxesSubplot(0.125,0.125;0.775x0.755)
# 151    AxesSubplot(0.125,0.125;0.775x0.755)
# 154    AxesSubplot(0.125,0.125;0.775x0.755)
# 156    AxesSubplot(0.125,0.125;0.775x0.755)
# 158    AxesSubplot(0.125,0.125;0.775x0.755)
# 159    AxesSubplot(0.125,0.125;0.775x0.755)
# 162    AxesSubplot(0.125,0.125;0.775x0.755)
# 164    AxesSubplot(0.125,0.125;0.775x0.755)
# 178    AxesSubplot(0.125,0.125;0.775x0.755)
# 181    AxesSubplot(0.125,0.125;0.775x0.755)
# 202    AxesSubplot(0.125,0.125;0.775x0.755)
# 205    AxesSubplot(0.125,0.125;0.775x0.755)
# 212    AxesSubplot(0.125,0.125;0.775x0.755)
# 215    AxesSubplot(0.125,0.125;0.775x0.755)
# 216    AxesSubplot(0.125,0.125;0.775x0.755)
# 219    AxesSubplot(0.125,0.125;0.775x0.755)
# 220    AxesSubplot(0.125,0.125;0.775x0.755)
# 221    AxesSubplot(0.125,0.125;0.775x0.755)
# 223    AxesSubplot(0.125,0.125;0.775x0.755)
# 224    AxesSubplot(0.125,0.125;0.775x0.755)
# 225    AxesSubplot(0.125,0.125;0.775x0.755)
# 230    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: price_usd, Length: 70, dtype: object

# %%
df.groupby("prop_country_id").price_usd.mean().sort_values()
# Out:
# prop_country_id
# 164     49.199259
# 162     61.889333
# 86      80.606000
# 158     86.504634
# 178     90.253611
# 9       90.354839
# 98      95.904303
# 154     96.263846
# 81      97.017937
# 223    100.193548
# 221    100.922549
# 72     102.384615
# 35     108.439397
# 41     111.213043
# 37     111.865000
# 117    113.481547
# 16     115.451613
# 70     121.927273
# 225    123.069302
# 59     128.085000
# 215    128.577597
# 53     129.888605
# 124    129.954286
# 60     131.826413
# 4      138.527130
# 100    138.959356
# 88     139.911111
# 26     140.976250
# 56     145.412540
# 181    146.330000
#           ...
# 129    166.168964
# 48     167.164333
# 202    169.653529
# 109    170.617308
# 132    175.205658
# 18     176.103871
# 138    176.612742
# 55     179.270430
# 31     184.154941
# 50     185.799074
# 15     189.442757
# 216    193.043082
# 99     194.947564
# 205    199.991991
# 230    200.000000
# 23     231.272727
# 220    231.597878
# 39     237.557714
# 119    256.250000
# 22     263.482759
# 134    271.000000
# 13     274.891250
# 90     277.461538
# 34     278.866552
# 27     306.000000
# 112    330.202857
# 32     355.545306
# 159    372.214286
# 151    410.923929
# 156    622.137273
# Name: price_usd, Length: 70, dtype: float64

# %%
import sklearn
from sklearn import cluster

# Convert DataFrame to matrix
mat = df.groupby("prop_country_id").price_usd.describe()[['mean','std']].values
# Using sklearn
km = cluster.KMeans(n_clusters=4)
km.fit(mat)
# Get cluster assignment labels
labels = km.labels_
# Format results as a DataFrame
results = pd.DataFrame([df.groupby("prop_country_id").price_usd.describe()[['mean','std']].index,labels]).T

# %%
scatter_data = df.groupby("prop_country_id").price_usd.describe()[['mean','std']]
scatter_data = pd.concat([scatter_data, results.set_index(0)], axis=1) 
scatter_data.rename(columns={1:'country_cluster'},inplace=True)

# %%
ax = scatter_data.plot(kind='scatter', x='mean', y='std', c='country_cluster', colormap='viridis')

# %%
k = 4

mat = df.groupby("prop_country_id").price_usd.describe()[['mean','std']].values
# Using sklearn
km = cluster.KMeans(n_clusters=k)
km.fit(mat)
# Get cluster assignment labels
labels = km.labels_
# Format results as a DataFrame
results = pd.DataFrame([df.groupby("prop_country_id").price_usd.describe()[['mean','std']].index,labels]).T

df["country_cluster"] = results.set_index(0).loc[df.prop_country_id].values

df.groupby("country_cluster").price_usd.plot.kde(xlim=(0,3500))
df.groupby("country_cluster").price_usd.describe()
# Out:
#                    count        mean         std     min      25%     50%  \
# country_cluster
# 0                  120.0  351.881000  317.224465  107.08  181.920  260.36
# 1                20984.0  147.445556  112.170530   10.21   83.000  119.00
# 2                   22.0  622.137273  686.464775   72.41  107.615  169.47
# 3                 3715.0  192.534062  144.593710    0.61  103.195  154.20
#
#                        75%      max
# country_cluster
# 0                 402.6525  2171.89
# 1                 177.0400  3500.00
# 2                1045.7125  1900.83
# 3                 234.0000  1669.12

# %%
for i in range (df["country_cluster"].max() + 1):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
df.drop('index',axis=1, inplace=True)

# %%
# df.loc[df['visitor_hist_adr_usd'] > 0].groupby("visitor_location_country_id").visitor_hist_adr_usd.describe()[['mean','std']]

df.loc[df['visitor_hist_adr_usd'] > 0].groupby("visitor_location_country_id").visitor_hist_adr_usd.describe()[['mean']].plot.pie(subplots=True)

# df.loc[df['visitor_hist_adr_usd'] > 0].groupby("visitor_location_country_id").visitor_hist_adr_usd.describe()[['mean']]
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001DF9E4BF470>],
#       dtype=object)

# %%
df.loc[df['booking_bool']].groupby("visitor_location_country_id").price_usd.describe()[['mean']].plot.pie(subplots=True)
# df.loc[df['booking_bool']].groupby("visitor_location_country_id").price_usd.plot.kde()
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001DF9D4FFE10>],
#       dtype=object)

# %%
df.groupby("prop_country_id").price_usd.describe().head()
# Out:
#                  count        mean         std     min       25%      50%  \
# prop_country_id
# 4                108.0  138.527130   75.370172   19.07   86.7925  115.625
# 9                 31.0   90.354839   67.858455   17.00   35.0000   70.000
# 13                 8.0  274.891250   50.499118  201.59  250.2200  267.200
# 15               185.0  189.442757  144.736897   60.00  107.0000  141.460
# 16                31.0  115.451613   73.467380   47.00   65.5000   87.000
#
#                       75%      max
# prop_country_id
# 4                173.2500   362.42
# 9                130.0000   250.00
# 13               296.7025   363.21
# 15               227.0000  1361.00
# 16               161.0000   341.00

# %%
# df.position
# assert 'not_real' in df.columns, ("Not valid column")
assert 'position' in df.columns

# %%
booker_bools = df.groupby('prop_id')['booking_bool'].sum()/df.groupby('prop_id')['booking_bool'].count()

clicker_bools = df.groupby('prop_id')['click_bool'].sum()/df.groupby('prop_id')['click_bool'].count()

# %%
to_dict = df.groupby('prop_id')['position'].describe()[['mean','std']]

# %%
to_dict.fillna({'std': 0}, inplace=True)

# %%
to_dict['click_ratio'] = clicker_bools
to_dict['book_ratio'] = booker_bools

# %%
to_dict['mean'].head()
# Out:
# prop_id
# 1     35.0
# 3     35.0
# 5     28.0
# 11    27.0
# 16    20.0
# Name: mean, dtype: float64
